# %%
import pandas as pd
import numpy as numpy
df = pd.read_csv("C:/Users/anuryadav/Desktop/Python/fraud_detection/batch/FilteredData.csv");
data = df.values
no_of_rows, no_of_col = data.shape

i=0

for row in data:
    flag = False 
   # print("Needs Validation ",data.item((i,0)), data.item((i+1,0)))
    if data.item((i,0)) == data.item((i+1,0)):        
        #print("flag as error", data.item((i,1)), data.item((i+1,1)))
        if data.item((i,3)) != data.item((i+1,3)):
            data.itemset((i,3),0)
        else:
            data.itemset((i,3),1)
            #print("flag as error col 3 RULE_TOT_INC_AMT row no",i, "data:", data.item((i,3)), data.item((i+1,3)))
            flag = True
        if data.item((i,4)) != data.item((i+1,4)):
            data.itemset((i,4),0)
        else:
            data.itemset((i,4),1)
           # print("flag as error col 4 RULE_AID_REQUEST_SW ",i, "data:", data.item((i,4)), data.item((i+1,4)))
            flag = True
        if data.item((i,5)) != data.item((i+1,5)):
            data.itemset((i,5),0)
        else:
            data.itemset((i,5),1)
            #print("flag as error col 3 RULE_ACTIVE_IN_CASE_SW ",i, "data:", data.item((i,5)), data.item((i+1,5)))
            flag = True
        if data.item((i,6)) != data.item((i+1,6)):
            data.itemset((i,6),0)
        else:
            data.itemset((i,6),1)
            #print("flag as error col 4 US_CITIZEN_SW ",i, "data:", data.item((i,6)), data.item((i+1,6)))
            flag = True
        if data.item((i,7)) != data.item((i+1,7)):
            data.itemset((i,7),0)
        else:
            data.itemset((i,7),1)
            #print("flag as error col 3 RULE_RESIDENCY_STATE_CD ",i, "data:", data.item((i,7)), data.item((i+1,7)))
            flag = True
        if data.item((i,8)) != data.item((i+1,8)):
            data.itemset((i,8),0)
        else:
            data.itemset((i,8),1)
            #print("flag as error col 4 PROG_CD ",i, "data:", data.item((i,8)), data.item((i+1,8)))
            flag = True
    else:
        data.itemset((i,0),True)
        print("delete  row no: ",i)
        
   # if(flag == True):
        #print("Error in row no: ",i)
    i=i+1
    
    if i == no_of_rows - 1:
        break
print(data)
for row in data:
    if data.item(i,0) == True:
        data = numpy.delete(data, (i), axis=0)
        print("deleting  row no: ",i)
print(data)     
dfsave=pd.DataFrame(data)

dfsave.to_csv(r'C:/Users/anuryadav/Desktop/Python/fraud_detection/batch/pandas_batch.csv', sep=',', index=False, header=True)
# Out:
# delete  row no:  0
# delete  row no:  20
# delete  row no:  47
# delete  row no:  48
# delete  row no:  49
# [[True 193132 False 1 1 0 'Y' 0 'MA']
#  [243040 429688 False 0 1 1 1 1 1]
#  [243040 429688 True 0 1 1 1 1 1]
#  [243040 429688 True 0 0 1 1 1 1]
#  [243040 429688 True 1 0 1 1 1 1]
#  [243040 429688 True 0 0 1 1 1 1]
#  [243040 429688 False 0 0 1 1 1 1]
#  [243040 429688 True 0 1 1 1 1 1]
#  [243040 429688 True 0 0 1 1 1 1]
#  [243040 429688 True 1 0 1 1 1 1]
#  [243040 429688 True 0 0 1 1 1 1]
#  [243040 429711 False 0 0 1 1 1 1]
#  [243040 429711 True 1 1 1 1 1 1]
#  [243040 429711 True 0 0 1 1 1 1]
#  [243040 429711 True 1 0 1 1 1 1]
#  [243040 429711 True 0 0 1 1 1 1]
#  [243040 429711 False 1 0 1 1 1 1]
#  [243040 429711 True 1 1 1 1 1 1]
#  [243040 429711 True 1 0 1 1 1 1]
#  [243040 429711 True 0 0 1 1 1 1]
#  [True 429711 True 1 0 0 'Y' 0 'MA']
#  [500853788 1000683107 False 0 1 1 1 1 1]
#  [500853788 1000683107 True 1 1 1 1 1 1]
#  [500853788 1000683107 True 0 1 1 1 1 1]
#  [500853788 1000683107 True 0 1 1 1 1 1]
#  [500853788 1000683107 True 0 1 1 1 1 1]
#  [500853788 1000683107 False 0 1 1 1 1 1]
#  [500853788 1000683107 True 1 1 1 1 1 1]
#  [500853788 1000683107 True 0 1 1 1 1 1]
#  [500853788 1000683107 True 1 1 1 1 1 1]
#  [500853788 1000683107 True 1 1 1 1 1 1]
#  [500853788 1000683107 False 0 1 1 1 1 1]
#  [500853788 1000683107 True 0 1 1 1 1 1]
#  [500853788 1000683107 True 1 1 1 1 1 1]
#  [500853788 1000683107 True 1 1 1 1 1 1]
#  [500853788 1000683623 False 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 0 1 1]
#  [500853788 1000683623 True 1 1 1 0 1 1]
#  [500853788 1000683623 False 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 0 1 1]
#  [500853788 1000683623 True 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 0 1 1]
#  [500853788 1000683623 False 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 0 1 1]
#  [True 1000683623 True 1 0 0 'N' 0 'MA']
#  [True 507957 False 1 0 0 'Y' 0 'MA']
#  [True 512659 False 1 1 0 'Y' 0 'MA']
#  [775024350 304191 False 1 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 0 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 1 1]
#  [775024350 304191 False 0 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 1 1 1 1 1 1]
#  [775024350 304191 True 0 1 1 1 1 1]
#  [775024350 304191 False 0 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 1 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 1 1]
#  [775024350 304191 False 1 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 1 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 1 1]
#  [775024350 304191 True 1 0 0 'Y' 0 'MA']]
# [[True 193132 False 1 1 0 'Y' 0 'MA']
#  [243040 429688 False 0 1 1 1 1 1]
#  [243040 429688 True 0 1 1 1 1 1]
#  [243040 429688 True 0 0 1 1 1 1]
#  [243040 429688 True 1 0 1 1 1 1]
#  [243040 429688 True 0 0 1 1 1 1]
#  [243040 429688 False 0 0 1 1 1 1]
#  [243040 429688 True 0 1 1 1 1 1]
#  [243040 429688 True 0 0 1 1 1 1]
#  [243040 429688 True 1 0 1 1 1 1]
#  [243040 429688 True 0 0 1 1 1 1]
#  [243040 429711 False 0 0 1 1 1 1]
#  [243040 429711 True 1 1 1 1 1 1]
#  [243040 429711 True 0 0 1 1 1 1]
#  [243040 429711 True 1 0 1 1 1 1]
#  [243040 429711 True 0 0 1 1 1 1]
#  [243040 429711 False 1 0 1 1 1 1]
#  [243040 429711 True 1 1 1 1 1 1]
#  [243040 429711 True 1 0 1 1 1 1]
#  [243040 429711 True 0 0 1 1 1 1]
#  [True 429711 True 1 0 0 'Y' 0 'MA']
#  [500853788 1000683107 False 0 1 1 1 1 1]
#  [500853788 1000683107 True 1 1 1 1 1 1]
#  [500853788 1000683107 True 0 1 1 1 1 1]
#  [500853788 1000683107 True 0 1 1 1 1 1]
#  [500853788 1000683107 True 0 1 1 1 1 1]
#  [500853788 1000683107 False 0 1 1 1 1 1]
#  [500853788 1000683107 True 1 1 1 1 1 1]
#  [500853788 1000683107 True 0 1 1 1 1 1]
#  [500853788 1000683107 True 1 1 1 1 1 1]
#  [500853788 1000683107 True 1 1 1 1 1 1]
#  [500853788 1000683107 False 0 1 1 1 1 1]
#  [500853788 1000683107 True 0 1 1 1 1 1]
#  [500853788 1000683107 True 1 1 1 1 1 1]
#  [500853788 1000683107 True 1 1 1 1 1 1]
#  [500853788 1000683623 False 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 0 1 1]
#  [500853788 1000683623 True 1 1 1 0 1 1]
#  [500853788 1000683623 False 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 0 1 1]
#  [500853788 1000683623 True 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 0 1 1]
#  [500853788 1000683623 False 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 1 1 1]
#  [500853788 1000683623 True 1 1 1 0 1 1]
#  [True 1000683623 True 1 0 0 'N' 0 'MA']
#  [True 507957 False 1 0 0 'Y' 0 'MA']
#  [True 512659 False 1 1 0 'Y' 0 'MA']
#  [775024350 304191 False 1 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 0 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 1 1]
#  [775024350 304191 False 0 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 1 1 1 1 1 1]
#  [775024350 304191 True 0 1 1 1 1 1]
#  [775024350 304191 False 0 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 1 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 1 1]
#  [775024350 304191 False 1 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 0 1]
#  [775024350 304191 True 1 1 1 1 1 1]
#  [775024350 304191 True 1 1 1 1 1 1]
#  [775024350 304191 True 1 0 0 'Y' 0 'MA']]

# %%
import pandas as pd
df = pd.read_csv("C:/Users/anuryadav/Desktop/Python/fraud_detection/batch/FilteredData.csv");
data = df.values
no_of_rows, no_of_col = data.shape

# %%
numpy.delete(data, (0), axis=0)
# Out:
# array([[243040, 429688, False, False, True, True, True, True, True],
#        [243040, 429688, True, False, True, True, True, True, True],
#        [243040, 429688, True, False, False, True, True, True, True],
#        [243040, 429688, True, True, False, True, True, True, True],
#        [243040, 429688, True, False, False, True, True, True, True],
#        [243040, 429688, False, False, False, True, True, True, True],
#        [243040, 429688, True, False, True, True, True, True, True],
#        [243040, 429688, True, False, False, True, True, True, True],
#        [243040, 429688, True, True, False, True, True, True, True],
#        [243040, 429688, True, False, False, True, True, True, True],
#        [243040, 429711, False, False, False, True, True, True, True],
#        [243040, 429711, True, True, True, True, True, True, True],
#        [243040, 429711, True, False, False, True, True, True, True],
#        [243040, 429711, True, True, False, True, True, True, True],
#        [243040, 429711, True, False, False, True, True, True, True],
#        [243040, 429711, False, True, False, True, True, True, True],
#        [243040, 429711, True, True, True, True, True, True, True],
#        [243040, 429711, True, True, False, True, True, True, True],
#        [243040, 429711, True, False, False, True, True, True, True],
#        [243040, 429711, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, False, False, True, True, True, True,
#         True],
#        [500853788, 1000683107, True, True, True, True, True, True, True],
#        [500853788, 1000683107, True, False, True, True, True, True, True],
#        [500853788, 1000683107, True, False, True, True, True, True, True],
#        [500853788, 1000683107, True, False, True, True, True, True, True],
#        [500853788, 1000683107, False, False, True, True, True, True,
#         True],
#        [500853788, 1000683107, True, True, True, True, True, True, True],
#        [500853788, 1000683107, True, False, True, True, True, True, True],
#        [500853788, 1000683107, True, True, True, True, True, True, True],
#        [500853788, 1000683107, True, True, True, True, True, True, True],
#        [500853788, 1000683107, False, False, True, True, True, True,
#         True],
#        [500853788, 1000683107, True, False, True, True, True, True, True],
#        [500853788, 1000683107, True, True, True, True, True, True, True],
#        [500853788, 1000683107, True, True, True, True, True, True, True],
#        [500853788, 1000683623, False, True, True, True, True, True, True],
#        [500853788, 1000683623, True, True, True, True, True, True, True],
#        [500853788, 1000683623, True, True, True, True, False, True, True],
#        [500853788, 1000683623, True, True, True, True, False, True, True],
#        [500853788, 1000683623, False, True, True, True, True, True, True],
#        [500853788, 1000683623, True, True, True, True, True, True, True],
#        [500853788, 1000683623, True, True, True, True, False, True, True],
#        [500853788, 1000683623, True, True, True, True, True, True, True],
#        [500853788, 1000683623, True, True, True, True, False, True, True],
#        [500853788, 1000683623, False, True, True, True, True, True, True],
#        [500853788, 1000683623, True, True, True, True, True, True, True],
#        [500853788, 1000683623, True, True, True, True, False, True, True],
#        [500853788, 1000683623, True, 1, 0, 0, 'N', 0, 'MA'],
#        [501131546, 507957, False, 1, 0, 0, 'Y', 0, 'MA'],
#        [501141907, 512659, False, 1, 1, 0, 'Y', 0, 'MA'],
#        [775024350, 304191, False, True, True, True, True, True, True],
#        [775024350, 304191, True, True, True, True, True, False, True],
#        [775024350, 304191, True, True, True, True, True, False, True],
#        [775024350, 304191, True, False, True, True, True, True, True],
#        [775024350, 304191, True, True, True, True, True, True, True],
#        [775024350, 304191, False, False, True, True, True, True, True],
#        [775024350, 304191, True, True, True, True, True, False, True],
#        [775024350, 304191, True, True, True, True, True, False, True],
#        [775024350, 304191, True, True, True, True, True, True, True],
#        [775024350, 304191, True, False, True, True, True, True, True],
#        [775024350, 304191, False, False, True, True, True, True, True],
#        [775024350, 304191, True, True, True, True, True, False, True],
#        [775024350, 304191, True, True, True, True, True, False, True],
#        [775024350, 304191, True, True, True, True, True, True, True],
#        [775024350, 304191, True, True, True, True, True, True, True],
#        [775024350, 304191, False, True, True, True, True, True, True],
#        [775024350, 304191, True, True, True, True, True, False, True],
#        [775024350, 304191, True, True, True, True, True, True, True],
#        [775024350, 304191, True, True, True, True, True, True, True],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 0, 'MA']], dtype=object)

# %%
dfsave.to_csv(r'C:/Users/anuryadav/Desktop/Python/fraud_detection/batch/pandas_batch.csv', sep=',', index=False, header=True)

# %%
df = pd.read_csv("C:/Users/anuryadav/Desktop/Deskpot/FI/FilteredData.csv");

# %%
data = df.values

# %%
data
# Out:
# array([[118109, 193132, False, 1, 1, 0, 'Y', 0, 'MA'],
#        [243040, 429688, False, 1, 0, 0, 'Y', 0, 'MA'],
#        [243040, 429688, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [243040, 429688, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [243040, 429688, True, 0, 1, 0, 'Y', 0, 'MA'],
#        [243040, 429688, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [243040, 429688, False, 1, 1, 0, 'Y', 0, 'MA'],
#        [243040, 429688, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [243040, 429688, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [243040, 429688, True, 0, 1, 0, 'Y', 0, 'MA'],
#        [243040, 429688, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [243040, 429711, False, 1, 1, 0, 'Y', 0, 'MA'],
#        [243040, 429711, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [243040, 429711, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [243040, 429711, True, 1, 1, 0, 'Y', 0, 'MA'],
#        [243040, 429711, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [243040, 429711, False, 0, 1, 0, 'Y', 0, 'MA'],
#        [243040, 429711, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [243040, 429711, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [243040, 429711, True, 0, 1, 0, 'Y', 0, 'MA'],
#        [243040, 429711, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, False, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, False, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, False, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, True, 0, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683107, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683623, False, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683623, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683623, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683623, True, 1, 0, 0, 'N', 0, 'MA'],
#        [500853788, 1000683623, False, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683623, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683623, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683623, True, 1, 0, 0, 'N', 0, 'MA'],
#        [500853788, 1000683623, True, 1, 0, 0, 'N', 0, 'MA'],
#        [500853788, 1000683623, False, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683623, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683623, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [500853788, 1000683623, True, 1, 0, 0, 'N', 0, 'MA'],
#        [501131546, 507957, False, 1, 0, 0, 'Y', 0, 'MA'],
#        [501141907, 512659, False, 1, 1, 0, 'Y', 0, 'MA'],
#        [775024350, 304191, False, 1, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, True, 0, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, False, 0, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, False, 0, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, False, 1, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 1, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 0, 'MA'],
#        [775024350, 304191, True, 1, 0, 0, 'Y', 0, 'MA']], dtype=object)

# %%
no_of_rows, no_of_col = data.shape

# %%
type(no_of_rows)
# Out:
# int

# %%
i=0

for row in data:
   # print("Needs Validation ",data.item((i,0)), data.item((i+1,0)))
    if data.item((i,0)) == data.item((i+1,0)):
        
        print("Needs Validation ",data.item((i,0)) , data.item((i+1,0)))
    i=i+1
    if i == no_of_rows - 1:
        break
# Out:
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  243040 243040
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  500853788 500853788
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350
# Needs Validation  775024350 775024350

# %%
i=0

for row in data:
    flag = False 
   # print("Needs Validation ",data.item((i,0)), data.item((i+1,0)))
    if data.item((i,0)) == data.item((i+1,0)):        
        #print("flag as error", data.item((i,1)), data.item((i+1,1)))
        if data.item((i,3)) != data.item((i+1,3)):
          #  print("flag as error col 3 RULE_TOT_INC_AMT row no",i, "data:", data.item((i,3)), data.item((i+1,3)))
            flag = True
        if data.item((i,4)) != data.item((i+1,4)):
           # print("flag as error col 4 RULE_AID_REQUEST_SW ",i, "data:", data.item((i,4)), data.item((i+1,4)))
            flag = True
        if data.item((i,5)) != data.item((i+1,5)):
            #print("flag as error col 3 RULE_ACTIVE_IN_CASE_SW ",i, "data:", data.item((i,5)), data.item((i+1,5)))
            flag = True
        if data.item((i,6)) != data.item((i+1,6)):
            #print("flag as error col 4 US_CITIZEN_SW ",i, "data:", data.item((i,6)), data.item((i+1,6)))
            flag = True
        if data.item((i,7)) != data.item((i+1,7)):
            #print("flag as error col 3 RULE_RESIDENCY_STATE_CD ",i, "data:", data.item((i,7)), data.item((i+1,7)))
            flag = True
        if data.item((i,8)) != data.item((i+1,8)):
            #print("flag as error col 4 PROG_CD ",i, "data:", data.item((i,8)), data.item((i+1,8)))
            flag = True

    if(flag == True):
        print("Error in row no: ",i)
    i=i+1
    
    if i == no_of_rows - 1:
        break
# Out:
# Error in row no:  1
# Error in row no:  2
# Error in row no:  3
# Error in row no:  4
# Error in row no:  5
# Error in row no:  6
# Error in row no:  7
# Error in row no:  8
# Error in row no:  9
# Error in row no:  10
# Error in row no:  11
# Error in row no:  13
# Error in row no:  14
# Error in row no:  15
# Error in row no:  16
# Error in row no:  18
# Error in row no:  19
# Error in row no:  21
# Error in row no:  23
# Error in row no:  24
# Error in row no:  25
# Error in row no:  26
# Error in row no:  28
# Error in row no:  31
# Error in row no:  32
# Error in row no:  37
# Error in row no:  38
# Error in row no:  41
# Error in row no:  43
# Error in row no:  46
# Error in row no:  51
# Error in row no:  52
# Error in row no:  53
# Error in row no:  55
# Error in row no:  56
# Error in row no:  57
# Error in row no:  59
# Error in row no:  60
# Error in row no:  61
# Error in row no:  62
# Error in row no:  66

# %%
data.item((1,3))
# Out:
# 1

# %%
type(data.item((1,1)))
# Out:
# int

# %%
df.ACTIVE_IN_CASE_SW
# Out:
# 0     Y
# 1     Y
# 2     Y
# 3     Y
# 4     Y
# 5     Y
# 6     Y
# 7     Y
# 8     Y
# 9     Y
# 10    Y
# 11    Y
# 12    Y
# 13    Y
# 14    Y
# 15    Y
# 16    Y
# 17    Y
# 18    Y
# 19    Y
# 20    Y
# 21    Y
# 22    Y
# 23    Y
# 24    Y
# 25    Y
# 26    Y
# 27    Y
# 28    Y
# 29    Y
#      ..
# 40    Y
# 41    Y
# 42    Y
# 43    Y
# 44    Y
# 45    Y
# 46    Y
# 47    Y
# 48    Y
# 49    Y
# 50    Y
# 51    Y
# 52    Y
# 53    Y
# 54    Y
# 55    Y
# 56    Y
# 57    Y
# 58    Y
# 59    Y
# 60    Y
# 61    Y
# 62    Y
# 63    Y
# 64    Y
# 65    Y
# 66    Y
# 67    Y
# 68    Y
# 69    Y
# Name: ACTIVE_IN_CASE_SW, Length: 70, dtype: object

# %%
row = next(df.iterrows())[1]

# %%
typerow
# Out:
#   File "<ipython-input-19-9a5cda948e09>", line 1
#     type row
#            ^
# SyntaxError: invalid syntax

# %%
flag = "first";
for index, row in dfiterrows():
    print(index)
    pr
    if index != 0:
        print(row[1])
# Out:
# 0
# 1
# 429688
# 2
# 429688
# 3
# 429688
# 4
# 429688
# 5
# 429688
# 6
# 429688
# 7
# 429688
# 8
# 429688
# 9
# 429688
# 10
# 429688
# 11
# 429711
# 12
# 429711
# 13
# 429711
# 14
# 429711
# 15
# 429711
# 16
# 429711
# 17
# 429711
# 18
# 429711
# 19
# 429711
# 20
# 429711
# 21
# 1000683107
# 22
# 1000683107
# 23
# 1000683107
# 24
# 1000683107
# 25
# 1000683107
# 26
# 1000683107
# 27
# 1000683107
# 28
# 1000683107
# 29
# 1000683107
# 30
# 1000683107
# 31
# 1000683107
# 32
# 1000683107
# 33
# 1000683107
# 34
# 1000683107
# 35
# 1000683623
# 36
# 1000683623
# 37
# 1000683623
# 38
# 1000683623
# 39
# 1000683623
# 40
# 1000683623
# 41
# 1000683623
# 42
# 1000683623
# 43
# 1000683623
# 44
# 1000683623
# 45
# 1000683623
# 46
# 1000683623
# 47
# 1000683623
# 48
# 507957
# 49
# 512659
# 50
# 304191
# 51
# 304191
# 52
# 304191
# 53
# 304191
# 54
# 304191
# 55
# 304191
# 56
# 304191
# 57
# 304191
# 58
# 304191
# 59
# 304191
# 60
# 304191
# 61
# 304191
# 62
# 304191
# 63
# 304191
# 64
# 304191
# 65
# 304191
# 66
# 304191
# 67
# 304191
# 68
# 304191
# 69
# 304191

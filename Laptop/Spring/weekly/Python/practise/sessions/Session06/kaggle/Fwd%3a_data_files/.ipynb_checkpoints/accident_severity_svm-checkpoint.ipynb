# %%
import pandas as pd
from  sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn import tree
import graphviz
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score

# %%
accident_test = pd.read_csv("Accident_test.csv")

# %%
accident_train = pd.read_csv("Accident_train.csv" )

# %%
# Out:
# 150433

# %%
accident_train.head(10)
accident_train.head(10)
# Out:
#    Collision_Ref_No Policing_Area  Collision_Severity Weekday_of_Collision  \
# 0              3518          CREA                   3                  MON
# 1             10557          BELC                   3                  SAT
# 2              5002          LISB                   3                  WED
# 3             11714          BELC                   3                  SUN
# 4             12416          MIDU                   3                  MON
# 5               558          FOYL                   2                  MON
# 6              7372          ANTN                   2                  MON
# 7             11825          ARBC                   3                  SAT
# 8              7656          ARBC                   3                  TUE
# 9              5582          NABB                   3                  FRI
#
#    Day_of_Collision  Month_of_Collision  Hour_of_Collision  Carriageway_Type  \
# 0                 4                   8               14.0                13
# 1                 8                   8               17.0                11
# 2                 5                  11               17.0                 1
# 3                18                  10               16.0                12
# 4                23                  11                9.0                13
# 5                 3                   2               12.0                13
# 6                26                   1               16.0                13
# 7                24                  10               11.0                13
# 8                10                   2               15.0                 1
# 9                 5                  12                8.0                13
#
#    Speed_Limit  Junction_Detail  Junction_Control  Ped_Crossing_HC  \
# 0           60              1.0               1.0              1.0
# 1           50             12.0               7.0              1.0
# 2           60             12.0               7.0              1.0
# 3           70              6.0               NaN              1.0
# 4           60              6.0               7.0              1.0
# 5           60              1.0               1.0              1.0
# 6           40              6.0               7.0              1.0
# 7           60             10.0               7.0              1.0
# 8           30              NaN               1.0              1.0
# 9           30              1.0               1.0              1.0
#
#    Ped_Crossing_PC  Light_Conditions  Weather_Conditions  \
# 0              1.0                 2                   9
# 1              1.0                 4                   3
# 2              1.0                 2                   2
# 3              1.0                 1                   3
# 4              1.0                 2                   3
# 5              1.0                 2                   2
# 6              1.0                 1                   1
# 7              1.0                 1                  10
# 8              1.0                 1                   3
# 9              2.0                 7                  10
#
#    Road_Surface_Conditions  Special_Conditions_at_Site
# 0                      9.0                         1.0
# 1                      1.0                         1.0
# 2                      2.0                         1.0
# 3                      1.0                         1.0
# 4                      1.0                         1.0
# 5                      2.0                         1.0
# 6                      2.0                         5.0
# 7                      2.0                         NaN
# 8                      1.0                         1.0
# 9                      1.0                         1.0

# %%
# replace weekday_of_collisin with no
lable = LabelEncoder()
accident_train.Weekday_of_Collision=  lable.fit_transform(accident_train.Weekday_of_Collision)
#print(accident_train.head(10))

accident_test.Weekday_of_Collision=  lable.fit_transform(accident_test.Weekday_of_Collision)

# %%
accident_test.Weekday_of_Collision=  lable.fit_transform(accident_test.Weekday_of_Collision)

# %%
# get the labels out
labels = accident_train.Collision_Severity

# %%
labels.head(10)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# 5    2
# 6    2
# 7    3
# 8    3
# 9    3
# Name: Collision_Severity, dtype: int64

# %%
# drop Policing_Area as its string and not useful
accident_train = accident_train.drop(['Policing_Area', 'Collision_Ref_No','Collision_Severity'], axis=1)

# filling missing values with Mean of the column

accident_train.fillna(accident_train.mean(), inplace=True)

# %%
accident_train.head(10)
# Out:
#    Weekday_of_Collision  Day_of_Collision  Month_of_Collision  \
# 0                     1                 4                   8
# 1                     2                 8                   8
# 2                     6                 5                  11
# 3                     3                18                  10
# 4                     1                23                  11
# 5                     1                 3                   2
# 6                     1                26                   1
# 7                     2                24                  10
# 8                     5                10                   2
# 9                     0                 5                  12
#
#    Hour_of_Collision  Carriageway_Type  Speed_Limit  Junction_Detail  \
# 0               14.0                13           60         1.000000
# 1               17.0                11           50        12.000000
# 2               17.0                 1           60        12.000000
# 3               16.0                12           70         6.000000
# 4                9.0                13           60         6.000000
# 5               12.0                13           60         1.000000
# 6               16.0                13           40         6.000000
# 7               11.0                13           60        10.000000
# 8               15.0                 1           30         6.394042
# 9                8.0                13           30         1.000000
#
#    Junction_Control  Ped_Crossing_HC  Ped_Crossing_PC  Light_Conditions  \
# 0          1.000000              1.0              1.0                 2
# 1          7.000000              1.0              1.0                 4
# 2          7.000000              1.0              1.0                 2
# 3          4.151921              1.0              1.0                 1
# 4          7.000000              1.0              1.0                 2
# 5          1.000000              1.0              1.0                 2
# 6          7.000000              1.0              1.0                 1
# 7          7.000000              1.0              1.0                 1
# 8          1.000000              1.0              1.0                 1
# 9          1.000000              1.0              2.0                 7
#
#    Weather_Conditions  Road_Surface_Conditions  Special_Conditions_at_Site
# 0                   9                      9.0                    1.000000
# 1                   3                      1.0                    1.000000
# 2                   2                      2.0                    1.000000
# 3                   3                      1.0                    1.000000
# 4                   3                      1.0                    1.000000
# 5                   2                      2.0                    1.000000
# 6                   1                      2.0                    5.000000
# 7                  10                      2.0                    1.059767
# 8                   3                      1.0                    1.000000
# 9                  10                      1.0                    1.000000

# %%
# make all data come close to the mean and trim outliers
# Standardizing the features
x = StandardScaler().fit_transform(accident_train)

# finsing important fields with PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents)

# %%
labels.iloc[0:20]
# Out:
# 0     3
# 1     3
# 2     3
# 3     3
# 4     3
# 5     2
# 6     2
# 7     3
# 8     3
# 9     3
# 10    3
# 11    2
# 12    3
# 13    3
# 14    3
# 15    3
# 16    3
# 17    3
# 18    3
# 19    3
# Name: Collision_Severity, dtype: int64

# %%
# plot in a scatter plot

#plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
#plt.plot([0.6], [2.1], 'x', color='red', markeredgewidth=2, markersize=10)

plt.scatter(principalDf.iloc[0:300,0], principalDf.iloc[0:300,1], c=labels.iloc[0:300], cmap ='autumn')

# %%
# use when not using PCA and standardise scaling
principalDf= accident_train

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
X = accident_train
y = labels

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)

# %%
y_t

# %%
from sklearn.svm import SVC

# %%
svm_model_linear = SVC(gamma='auto',class_weight='balanced',kernel='poly', C=1).fit(X_train, y_train)

# %%
svm_prediction = svm_model_linear.predict(X_test)

# %%
svm_model_linear.score(X_test, y_test)
# Out:
# 0.8540442837776774

# %%
confusion_matrix(y_test, svm_prediction)

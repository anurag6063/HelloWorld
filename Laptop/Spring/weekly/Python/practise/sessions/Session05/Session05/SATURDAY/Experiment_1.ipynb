# %% [markdown]
# # Foundations of Artificial Intelligence and Machine Learning
# ## A Program by IIIT-H and TalentSprint
# #### To be done in the Lab

# %% [markdown]
# The objective of this experiment is to visualize how the data is non-linearly separable in the given space might become linearly separable in a different space.

# %% [markdown]
# In this experiment we will use a simple synthetic non-linear dataset - "non_linear.pkl" . The dataset consists of 2 classes and a total of 2000 samples of 2 dimensions each.

# %% [markdown]
# The following steps are performed in the experiment :
#
#     1. Visualizing the dataset
#     2. Projecting the data
#     3. Training the linear classifier
#     4. Visualizing the boundary in the old space

# %%
# Importing required Packages
import pickle
import matplotlib.pyplot as plt

# %%
# Setting up the file
dataset = "../Datasets/AIML_DS_NON-LINEAR_STD.pkl"

# %%
# Loading the data
raw_data = pickle.load( open(dataset, "rb" ) )
data = raw_data[0]
labels = raw_data[1]
print(data.shape, labels.shape)
# Out:
# (800, 2) (800,)

# %% [markdown]
# #### 1. Visualizing the dataset

# %%
## Visualize the dataset
plt.scatter(data[:,0], data[:,1], c=labels)
plt.show()

# %% [markdown]
# #### 2. Projecting the data

# %% [markdown]
# #### Exercise 1
#
# Project the data into a new space using a simple projection of $[x, y] - [x^2, y^2]$ and visualize the projected data.

# %%
projected_data = ????????
## plot the projected data
???????
plt.show()

# %% [markdown]
# #### 3. Train a linear classifier
#
# Since the projected data looks linearly separable, let us train a linear classifier on this data, calculate its accuracy and visualize the boundary in the new space.

# %% [markdown]
# #### Exercise 2
#
# Plot the decision boundary in the new space and calculate the accuracy

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

## Split into train and test splits
## Note: Provided data is already shuffled
TrainTestRatio = 0.80
train_samples = (int)(projected_data.shape[0]*0.8)
train_data = projected_data[:train_samples,:]
train_labels = labels[:train_samples]
test_data = projected_data[train_samples:,:]
test_labels = labels[train_samples:]

## train the linear classifier (Logistic Regression in this case)
logreg = LogisticRegression()
logreg.fit(train_data,train_labels)
pred = logreg.predict(test_data)

## the decision boundary will be of form aX+b, we need to note the a and b learned
coeff = logreg.coef_
intercept = logreg.intercept_
## choosing an approprite range for x
xx = np.linspace(-0.2, 0.70, 50)
print(coeff[:, 0])
print(intercept)
yy = -(coeff[:, 0] * xx + intercept) / coeff[:,1]

## plot the decision boundary
plt.scatter(test_data[:,0], test_data[:,1], c=test_labels)
## plot the decision boundary
# ????????????????
plt.show()

## calculate the accuracy
# acc = ???????????????
print("accuracy = ", acc)

# %% [markdown]
# #### 4. Visualize the boundary in the old space

# %% [markdown]
# This is a non-trivial step, therefore, to plot the decision boundary in the original space we will loop over the elements in the original space and find those elements whose projections are really close to the decision boundary obtained in the new space. Finally, we plot all these elements in the original space as the decision boundary.

# %% [markdown]
# #### Exercise 3
#
# Find all such elements close to the decision boundary and visualize them in the original space

# %%
thresh = 0.1
def closeToLine(elem):
    ## find distance of point "elem" from the decision boundary using coeff and intercept
    dist = ??????????????
    if dist<thresh:
        return True
    else:
        return False

boundary = []
for elem in data:
    ## Your code here
    ???????????????
print("number of elements chosen = ", len(boundary))

## plot all the data in the original and the points close to decision boundary obtained above 
## Your code here
???????????
plt.show()

# %% [markdown]
# #### Exercise 4
#
# Experiment with different projections to develop a better understanding of the problem via visualization.

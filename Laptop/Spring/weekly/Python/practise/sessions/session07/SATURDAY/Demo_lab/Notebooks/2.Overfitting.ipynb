# %% [markdown]
# # Multi Layered Perceptron (MLP) - A quick (re-)introduction usng PyTorch
#
# In this notebook, we will train a simple MLP on the [FashionMNIST](https://github.com/zalandoresearch/fashion-mnist) data set using PyTorch library

# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import torch.nn.init as weight_init
import matplotlib.pyplot as plt
import numpy as np
import random

from torch.utils.data import Subset

from loadFashionMNIST import FashionMNIST

torch.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ### Selecting gpu device if cuda is available

# %%
### To test whether GPU instance is present in the system of not.
use_cuda = torch.cuda.is_available()
print('Using PyTorch version:', torch.__version__, 'CUDA:', use_cuda)

device = torch.device("cuda" if use_cuda else "cpu")
# Out:
# Using PyTorch version: 0.4.1 CUDA: True

# %% [markdown]
# ### Define data set
#
# For the demo, we will consider only 1% (or 0.01 fraction) of the original training data. We will keep the entire test set as our test data.

# %%
train_dataset = FashionMNIST(split='train', frac=0.01)
test_dataset = FashionMNIST(split='test')

# %% [markdown]
# ### Create a training and a validation data set from the given train split
#
# We will split the given training data into train and val set based on 80-20 split

# %%
training_ratio = 0.8

length = len(train_dataset)
inds = np.arange(0, length)
random.shuffle(inds)
train_inds = inds[:round(training_ratio*length)]
val_inds = inds[round(training_ratio*length):]

train_set = Subset(train_dataset, train_inds)
val_set = Subset(train_dataset, val_inds)

# %% [markdown]
# ### Visualize data set

# %%
print('Number of training data: {}'.format(len(train_set)))
print('Number of validation data: {}'.format(len(val_set)))
print('Number of test data: {}'.format(len(test_dataset)))
print('Image dimensions: {}'.format(train_dataset[0][0].size()))
plt.figure()
plt.axis('off')
plt.imshow(train_dataset[0][0].squeeze().numpy(),cmap='gray')
# Out:
# Number of training data: 480
# Number of validation data: 120
# Number of test data: 10000
# Image dimensions: torch.Size([1, 28, 28])

# %% [markdown]
# ### Define a data loader

# %%
batch_size = 10
# loading the train data set
train_loader = torch.utils.data.DataLoader(dataset=train_set, 
                                           batch_size=batch_size, 
                                           shuffle=True)

# loading the validation data set
test_loader = torch.utils.data.DataLoader(dataset=val_set, 
                                          batch_size=batch_size, 
                                          shuffle=False)

# loading the test data set
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)

# %%
#Plotting 10 samples
for (X_train, y_train) in train_loader:
    pltsize=1
    plt.figure(figsize=(10*pltsize, pltsize))
    
    for i in range(10):
        plt.subplot(1,10,i+1)
        plt.axis('off')
        plt.imshow(X_train[i,:,:,:].numpy().reshape(28,28), cmap="gray")
    break

# %% [markdown]
# ### Define a simple MLP
#
# Let's define the network as a Python class. This Python class inherits functions from _nn.module_.
#
# There are three convenient functions that are defined in this class:
#
# - ### **\__init__()**:
# In this function, we shall declare all the layers of our neural network, including the number of neurons, non-linear activations, etc.
#
# - ### **forward()**:
# This is the function that is used to compute forward pass of the network. Here, we shall connect the different layers we had defined in \__init__, according to the network architecture we want to make. In this case, $x -> fc1 -> relu -> fc2 -> relu -> fc3 -> softmax/out$.
#
# "forward" can be called by calling the object of this class directly. For example:
#
# ```
# net = Network()
# out = net(x)
# ```
#
# - ### **backward()**:
# This function is used to compute gradients across the entire network, and is called from the loss function at the end of the network.
#
# ```
# loss.backward()
# ```
#
# We have to write the **__init__()** and **forward()** methods, and PyTorch will automatically generate a **backward()** method for computing the gradients for the backward pass.

# %%
# Hyper Parameters 
input_size = 784
hidden1_size = 512
hidden2_size = 256
num_classes = 10
num_epochs = 75
learning_rate = 0.1

# %%
class Net(nn.Module):
    def __init__(self, input_size, hidden1_size, hidden2_size, num_classes):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden1_size)
        self.fc2 = nn.Linear(hidden1_size, hidden2_size)
        self.fc3 = nn.Linear(hidden2_size, num_classes)
        
        #Weight Initialization
        for m in self.modules():
          if isinstance(m,nn.Linear):
            weight_init.xavier_normal_(m.weight)


    def forward(self, x):
        out = F.relu(self.fc1(x))
        out = F.relu(self.fc2(out))
        out = F.softmax(self.fc3(out), dim=1)
        return out

# %% [markdown]
# ### Creating MLP object and transfering it to GPU

# %%
net = Net(input_size, hidden1_size, hidden2_size, num_classes)
print(net)
net = net.to(device)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %% [markdown]
# ### Define loss and optimizer

# %%
# Cross entropy loss for optimizer
criterion = nn.CrossEntropyLoss()

# %%
# SGD for Optimizer
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate)

# %% [markdown]
# ### Train the MLP

# %%
# In each epoch
train_err = []
val_err = []

for epoch in range(num_epochs):
    # Train
    correct_train = 0
    total_train = 0
    
    # For each batch of images in train set
    for i, (images, labels) in enumerate(train_loader):
        
        
        images = images.view(-1, 28*28)
        labels = labels
        
        images, labels = images.to(device), labels.to(device)
        
        # Initialize gradients to 0
        optimizer.zero_grad()
        
        # Forward pass (this calls the "forward" function within Net)
        outputs = net(images)
        
        # Find the loss
        loss = criterion(outputs, labels)
        
        # Find the gradients of all weights using the loss
        loss.backward()
        
        # Update the weights using the optimizer
        # For e.g.: w = w - (delta_w)*lr
        optimizer.step()
        
        # Find the output by doing a forward pass through the network
        outputs = net(images)

        # Find the class of each sample by taking a max across the probabilities of each class
        _, predicted = torch.max(outputs.data, 1)

        # Increment 'total', and 'correct' according to whether the prediction was correct or not
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum()
        
        if (i+1) % 10 == 0:
            print ('Epoch [%d/%d], Step [%d], Loss: %.4f' 
                   %(epoch+1, num_epochs, i+1, loss.item()))
            
    print('Training accuracy for epoch {} is {}%'.format(epoch+1, (100 * correct_train / total_train)))
    train_err.append(100.0-(100 * correct_train / total_train))
    
    # Validation
    correct_val = 0
    total_val = 0

    # For each batch of images in test set
    with torch.set_grad_enabled(False):
        for images, labels in test_loader:

          # Get the images
          images = images.view(-1, 28*28)

          images = images.to(device)

          # Find the output by doing a forward pass through the network
          outputs = net(images)

          # Find the class of each sample by taking a max across the probabilities of each class
          _, predicted = torch.max(outputs.data, 1)

          # Increment 'total', and 'correct' according to whether the prediction was correct or not
          total_val += labels.size(0)
          correct_val += (predicted.cpu() == labels).sum()

    print('Validation accuracy for epoch {} is {}%'.format(epoch+1, (100 * correct_val / total_val)))
    val_err.append(100.0-(100 * correct_val / total_val))
# Out:
# Epoch [1/75], Step [10], Loss: 2.3118
# Epoch [1/75], Step [20], Loss: 2.2228
# Epoch [1/75], Step [30], Loss: 2.2478
# Epoch [1/75], Step [40], Loss: 2.1987
# Training accuracy for epoch 1 is 45%
# Validation accuracy for epoch 1 is 41%
# Epoch [2/75], Step [10], Loss: 2.1068
# Epoch [2/75], Step [20], Loss: 1.8873
# Epoch [2/75], Step [30], Loss: 1.9929
# Epoch [2/75], Step [40], Loss: 1.8853
# Training accuracy for epoch 2 is 63%
# Validation accuracy for epoch 2 is 48%
# Epoch [3/75], Step [10], Loss: 1.5547
# Epoch [3/75], Step [20], Loss: 1.8012
# Epoch [3/75], Step [30], Loss: 1.8232
# Epoch [3/75], Step [40], Loss: 1.6403
# Training accuracy for epoch 3 is 69%
# Validation accuracy for epoch 3 is 66%
# Epoch [4/75], Step [10], Loss: 1.8349
# Epoch [4/75], Step [20], Loss: 1.8580
# Epoch [4/75], Step [30], Loss: 1.8874
# Epoch [4/75], Step [40], Loss: 2.0359
# Training accuracy for epoch 4 is 75%
# Validation accuracy for epoch 4 is 67%
# Epoch [5/75], Step [10], Loss: 1.7018
# Epoch [5/75], Step [20], Loss: 1.9723
# Epoch [5/75], Step [30], Loss: 1.5942
# Epoch [5/75], Step [40], Loss: 1.8514
# Training accuracy for epoch 5 is 81%
# Validation accuracy for epoch 5 is 66%
# Epoch [6/75], Step [10], Loss: 1.9593
# Epoch [6/75], Step [20], Loss: 1.5612
# Epoch [6/75], Step [30], Loss: 1.7140
# Epoch [6/75], Step [40], Loss: 1.8237
# Training accuracy for epoch 6 is 81%
# Validation accuracy for epoch 6 is 70%
# Epoch [7/75], Step [10], Loss: 1.8620
# Epoch [7/75], Step [20], Loss: 1.7603
# Epoch [7/75], Step [30], Loss: 1.6613
# Epoch [7/75], Step [40], Loss: 1.7257
# Training accuracy for epoch 7 is 82%
# Validation accuracy for epoch 7 is 67%
# Epoch [8/75], Step [10], Loss: 1.6426
# Epoch [8/75], Step [20], Loss: 1.6815
# Epoch [8/75], Step [30], Loss: 1.6309
# Epoch [8/75], Step [40], Loss: 1.6549
# Training accuracy for epoch 8 is 81%
# Validation accuracy for epoch 8 is 71%
# Epoch [9/75], Step [10], Loss: 2.0115
# Epoch [9/75], Step [20], Loss: 1.8567
# Epoch [9/75], Step [30], Loss: 1.8500
# Epoch [9/75], Step [40], Loss: 1.7713
# Training accuracy for epoch 9 is 83%
# Validation accuracy for epoch 9 is 72%
# Epoch [10/75], Step [10], Loss: 1.7625
# Epoch [10/75], Step [20], Loss: 1.8152
# Epoch [10/75], Step [30], Loss: 1.7543
# Epoch [10/75], Step [40], Loss: 1.8934
# Training accuracy for epoch 10 is 84%
# Validation accuracy for epoch 10 is 71%
# Epoch [11/75], Step [10], Loss: 1.4873
# Epoch [11/75], Step [20], Loss: 1.6843
# Epoch [11/75], Step [30], Loss: 1.7028
# Epoch [11/75], Step [40], Loss: 1.6240
# Training accuracy for epoch 11 is 82%
# Validation accuracy for epoch 11 is 72%
# Epoch [12/75], Step [10], Loss: 1.4993
# Epoch [12/75], Step [20], Loss: 1.5525
# Epoch [12/75], Step [30], Loss: 1.6556
# Epoch [12/75], Step [40], Loss: 1.7136
# Training accuracy for epoch 12 is 84%
# Validation accuracy for epoch 12 is 73%
# Epoch [13/75], Step [10], Loss: 1.5390
# Epoch [13/75], Step [20], Loss: 1.5828
# Epoch [13/75], Step [30], Loss: 1.5084
# Epoch [13/75], Step [40], Loss: 1.6487
# Training accuracy for epoch 13 is 85%
# Validation accuracy for epoch 13 is 73%
# Epoch [14/75], Step [10], Loss: 1.6635
# Epoch [14/75], Step [20], Loss: 1.5755
# Epoch [14/75], Step [30], Loss: 1.5623
# Epoch [14/75], Step [40], Loss: 1.4707
# Training accuracy for epoch 14 is 85%
# Validation accuracy for epoch 14 is 73%
# Epoch [15/75], Step [10], Loss: 1.6812
# Epoch [15/75], Step [20], Loss: 1.6007
# Epoch [15/75], Step [30], Loss: 1.6545
# Epoch [15/75], Step [40], Loss: 1.5655
# Training accuracy for epoch 15 is 86%
# Validation accuracy for epoch 15 is 73%
# Epoch [16/75], Step [10], Loss: 1.5599
# Epoch [16/75], Step [20], Loss: 1.6681
# Epoch [16/75], Step [30], Loss: 1.6461
# Epoch [16/75], Step [40], Loss: 1.5724
# Training accuracy for epoch 16 is 87%
# Validation accuracy for epoch 16 is 74%
# Epoch [17/75], Step [10], Loss: 1.7498
# Epoch [17/75], Step [20], Loss: 1.6754
# Epoch [17/75], Step [30], Loss: 1.5651
# Epoch [17/75], Step [40], Loss: 1.6624
# Training accuracy for epoch 17 is 87%
# Validation accuracy for epoch 17 is 66%
# Epoch [18/75], Step [10], Loss: 1.5137
# Epoch [18/75], Step [20], Loss: 1.7414
# Epoch [18/75], Step [30], Loss: 1.4849
# Epoch [18/75], Step [40], Loss: 1.4762
# Training accuracy for epoch 18 is 86%
# Validation accuracy for epoch 18 is 74%
# Epoch [19/75], Step [10], Loss: 1.5842
# Epoch [19/75], Step [20], Loss: 1.4758
# Epoch [19/75], Step [30], Loss: 1.5974
# Epoch [19/75], Step [40], Loss: 1.8535
# Training accuracy for epoch 19 is 86%
# Validation accuracy for epoch 19 is 73%
# Epoch [20/75], Step [10], Loss: 1.5803
# Epoch [20/75], Step [20], Loss: 1.4690
# Epoch [20/75], Step [30], Loss: 1.6876
# Epoch [20/75], Step [40], Loss: 1.5253
# Training accuracy for epoch 20 is 86%
# Validation accuracy for epoch 20 is 73%
# Epoch [21/75], Step [10], Loss: 1.7041
# Epoch [21/75], Step [20], Loss: 1.5687
# Epoch [21/75], Step [30], Loss: 1.4686
# Epoch [21/75], Step [40], Loss: 1.4644
# Training accuracy for epoch 21 is 87%
# Validation accuracy for epoch 21 is 72%
# Epoch [22/75], Step [10], Loss: 1.6621
# Epoch [22/75], Step [20], Loss: 1.5643
# Epoch [22/75], Step [30], Loss: 1.6647
# Epoch [22/75], Step [40], Loss: 1.7450
# Training accuracy for epoch 22 is 86%
# Validation accuracy for epoch 22 is 74%
# Epoch [23/75], Step [10], Loss: 1.5633
# Epoch [23/75], Step [20], Loss: 1.4726
# Epoch [23/75], Step [30], Loss: 1.4731
# Epoch [23/75], Step [40], Loss: 1.7309
# Training accuracy for epoch 23 is 86%
# Validation accuracy for epoch 23 is 74%
# Epoch [24/75], Step [10], Loss: 1.4612
# Epoch [24/75], Step [20], Loss: 1.4812
# Epoch [24/75], Step [30], Loss: 1.6747
# Epoch [24/75], Step [40], Loss: 1.6773
# Training accuracy for epoch 24 is 87%
# Validation accuracy for epoch 24 is 73%
# Epoch [25/75], Step [10], Loss: 1.6645
# Epoch [25/75], Step [20], Loss: 1.4714
# Epoch [25/75], Step [30], Loss: 1.6705
# Epoch [25/75], Step [40], Loss: 1.4620
# Training accuracy for epoch 25 is 87%
# Validation accuracy for epoch 25 is 74%
# Epoch [26/75], Step [10], Loss: 1.6791
# Epoch [26/75], Step [20], Loss: 1.7582
# Epoch [26/75], Step [30], Loss: 1.4619
# Epoch [26/75], Step [40], Loss: 1.9585
# Training accuracy for epoch 26 is 88%
# Validation accuracy for epoch 26 is 73%
# Epoch [27/75], Step [10], Loss: 1.6590
# Epoch [27/75], Step [20], Loss: 1.4624
# Epoch [27/75], Step [30], Loss: 1.6917
# Epoch [27/75], Step [40], Loss: 1.7585
# Training accuracy for epoch 27 is 86%
# Validation accuracy for epoch 27 is 72%
# Epoch [28/75], Step [10], Loss: 1.4801
# Epoch [28/75], Step [20], Loss: 1.5591
# Epoch [28/75], Step [30], Loss: 1.5701
# Epoch [28/75], Step [40], Loss: 1.5722
# Training accuracy for epoch 28 is 87%
# Validation accuracy for epoch 28 is 74%
# Epoch [29/75], Step [10], Loss: 1.5050
# Epoch [29/75], Step [20], Loss: 1.6588
# Epoch [29/75], Step [30], Loss: 1.5636
# Epoch [29/75], Step [40], Loss: 1.6643
# Training accuracy for epoch 29 is 88%
# Validation accuracy for epoch 29 is 73%
# Epoch [30/75], Step [10], Loss: 1.5637
# Epoch [30/75], Step [20], Loss: 1.5890
# Epoch [30/75], Step [30], Loss: 1.5633
# Epoch [30/75], Step [40], Loss: 1.6647
# Training accuracy for epoch 30 is 87%
# Validation accuracy for epoch 30 is 73%
# Epoch [31/75], Step [10], Loss: 1.5020
# Epoch [31/75], Step [20], Loss: 1.5632
# Epoch [31/75], Step [30], Loss: 1.6987
# Epoch [31/75], Step [40], Loss: 1.5631
# Training accuracy for epoch 31 is 87%
# Validation accuracy for epoch 31 is 74%
# Epoch [32/75], Step [10], Loss: 1.4889
# Epoch [32/75], Step [20], Loss: 1.5634
# Epoch [32/75], Step [30], Loss: 1.5750
# Epoch [32/75], Step [40], Loss: 1.5683
# Training accuracy for epoch 32 is 87%
# Validation accuracy for epoch 32 is 74%
# Epoch [33/75], Step [10], Loss: 1.5593
# Epoch [33/75], Step [20], Loss: 1.4877
# Epoch [33/75], Step [30], Loss: 1.5654
# Epoch [33/75], Step [40], Loss: 1.4648
# Training accuracy for epoch 33 is 88%
# Validation accuracy for epoch 33 is 74%
# Epoch [34/75], Step [10], Loss: 1.4620
# Epoch [34/75], Step [20], Loss: 1.4703
# Epoch [34/75], Step [30], Loss: 1.5182
# Epoch [34/75], Step [40], Loss: 1.9319
# Training accuracy for epoch 34 is 87%
# Validation accuracy for epoch 34 is 74%
# Epoch [35/75], Step [10], Loss: 1.4629
# Epoch [35/75], Step [20], Loss: 1.5710
# Epoch [35/75], Step [30], Loss: 1.4664
# Epoch [35/75], Step [40], Loss: 1.5873
# Training accuracy for epoch 35 is 88%
# Validation accuracy for epoch 35 is 73%
# Epoch [36/75], Step [10], Loss: 1.8493
# Epoch [36/75], Step [20], Loss: 1.6564
# Epoch [36/75], Step [30], Loss: 1.7635
# Epoch [36/75], Step [40], Loss: 1.6709
# Training accuracy for epoch 36 is 88%
# Validation accuracy for epoch 36 is 74%
# Epoch [37/75], Step [10], Loss: 1.5627
# Epoch [37/75], Step [20], Loss: 1.5786
# Epoch [37/75], Step [30], Loss: 1.5740
# Epoch [37/75], Step [40], Loss: 1.6640
# Training accuracy for epoch 37 is 88%
# Validation accuracy for epoch 37 is 74%
# Epoch [38/75], Step [10], Loss: 1.6655
# Epoch [38/75], Step [20], Loss: 1.5572
# Epoch [38/75], Step [30], Loss: 1.5601
# Epoch [38/75], Step [40], Loss: 1.5605
# Training accuracy for epoch 38 is 88%
# Validation accuracy for epoch 38 is 74%
# Epoch [39/75], Step [10], Loss: 1.5627
# Epoch [39/75], Step [20], Loss: 1.7536
# Epoch [39/75], Step [30], Loss: 1.5643
# Epoch [39/75], Step [40], Loss: 1.5667
# Training accuracy for epoch 39 is 88%
# Validation accuracy for epoch 39 is 74%
# Epoch [40/75], Step [10], Loss: 1.5604
# Epoch [40/75], Step [20], Loss: 1.8600
# Epoch [40/75], Step [30], Loss: 1.5647
# Epoch [40/75], Step [40], Loss: 1.5637
# Training accuracy for epoch 40 is 88%
# Validation accuracy for epoch 40 is 74%
# Epoch [41/75], Step [10], Loss: 1.5614
# Epoch [41/75], Step [20], Loss: 1.6630
# Epoch [41/75], Step [30], Loss: 1.6771
# Epoch [41/75], Step [40], Loss: 1.5651
# Training accuracy for epoch 41 is 88%
# Validation accuracy for epoch 41 is 74%
# Epoch [42/75], Step [10], Loss: 1.4674
# Epoch [42/75], Step [20], Loss: 1.5615
# Epoch [42/75], Step [30], Loss: 1.5618
# Epoch [42/75], Step [40], Loss: 1.7548
# Training accuracy for epoch 42 is 88%
# Validation accuracy for epoch 42 is 74%
# Epoch [43/75], Step [10], Loss: 1.4650
# Epoch [43/75], Step [20], Loss: 1.5628
# Epoch [43/75], Step [30], Loss: 1.5995
# Epoch [43/75], Step [40], Loss: 1.5585
# Training accuracy for epoch 43 is 88%
# Validation accuracy for epoch 43 is 73%
# Epoch [44/75], Step [10], Loss: 1.4652
# Epoch [44/75], Step [20], Loss: 1.6614
# Epoch [44/75], Step [30], Loss: 1.5648
# Epoch [44/75], Step [40], Loss: 1.7673
# Training accuracy for epoch 44 is 88%
# Validation accuracy for epoch 44 is 73%
# Epoch [45/75], Step [10], Loss: 1.5618
# Epoch [45/75], Step [20], Loss: 1.6951
# Epoch [45/75], Step [30], Loss: 1.8586
# Epoch [45/75], Step [40], Loss: 1.4622
# Training accuracy for epoch 45 is 87%
# Validation accuracy for epoch 45 is 73%
# Epoch [46/75], Step [10], Loss: 1.5704
# Epoch [46/75], Step [20], Loss: 1.7602
# Epoch [46/75], Step [30], Loss: 1.5637
# Epoch [46/75], Step [40], Loss: 1.5582
# Training accuracy for epoch 46 is 88%
# Validation accuracy for epoch 46 is 73%
# Epoch [47/75], Step [10], Loss: 1.4616
# Epoch [47/75], Step [20], Loss: 1.5617
# Epoch [47/75], Step [30], Loss: 1.5383
# Epoch [47/75], Step [40], Loss: 1.6639
# Training accuracy for epoch 47 is 88%
# Validation accuracy for epoch 47 is 74%
# Epoch [48/75], Step [10], Loss: 1.5003
# Epoch [48/75], Step [20], Loss: 1.6554
# Epoch [48/75], Step [30], Loss: 1.7584
# Epoch [48/75], Step [40], Loss: 1.4643
# Training accuracy for epoch 48 is 88%
# Validation accuracy for epoch 48 is 74%
# Epoch [49/75], Step [10], Loss: 1.5653
# Epoch [49/75], Step [20], Loss: 1.4616
# Epoch [49/75], Step [30], Loss: 1.6619
# Epoch [49/75], Step [40], Loss: 1.6557
# Training accuracy for epoch 49 is 88%
# Validation accuracy for epoch 49 is 75%
# Epoch [50/75], Step [10], Loss: 1.6585
# Epoch [50/75], Step [20], Loss: 1.5980
# Epoch [50/75], Step [30], Loss: 1.5617
# Epoch [50/75], Step [40], Loss: 1.4640
# Training accuracy for epoch 50 is 88%
# Validation accuracy for epoch 50 is 74%
# Epoch [51/75], Step [10], Loss: 1.6619
# Epoch [51/75], Step [20], Loss: 1.6639
# Epoch [51/75], Step [30], Loss: 1.5628
# Epoch [51/75], Step [40], Loss: 1.5618
# Training accuracy for epoch 51 is 88%
# Validation accuracy for epoch 51 is 75%
# Epoch [52/75], Step [10], Loss: 1.4646
# Epoch [52/75], Step [20], Loss: 1.6605
# Epoch [52/75], Step [30], Loss: 1.4634
# Epoch [52/75], Step [40], Loss: 1.4615
# Training accuracy for epoch 52 is 88%
# Validation accuracy for epoch 52 is 74%
# Epoch [53/75], Step [10], Loss: 1.4632
# Epoch [53/75], Step [20], Loss: 1.5614
# Epoch [53/75], Step [30], Loss: 1.4656
# Epoch [53/75], Step [40], Loss: 1.6636
# Training accuracy for epoch 53 is 88%
# Validation accuracy for epoch 53 is 74%
# Epoch [54/75], Step [10], Loss: 1.5630
# Epoch [54/75], Step [20], Loss: 1.6638
# Epoch [54/75], Step [30], Loss: 1.4623
# Epoch [54/75], Step [40], Loss: 1.5622
# Training accuracy for epoch 54 is 88%
# Validation accuracy for epoch 54 is 74%
# Epoch [55/75], Step [10], Loss: 1.5582
# Epoch [55/75], Step [20], Loss: 1.5645
# Epoch [55/75], Step [30], Loss: 1.5633
# Epoch [55/75], Step [40], Loss: 1.5617
# Training accuracy for epoch 55 is 88%
# Validation accuracy for epoch 55 is 74%
# Epoch [56/75], Step [10], Loss: 1.4664
# Epoch [56/75], Step [20], Loss: 1.4627
# Epoch [56/75], Step [30], Loss: 1.4653
# Epoch [56/75], Step [40], Loss: 1.4639
# Training accuracy for epoch 56 is 88%
# Validation accuracy for epoch 56 is 74%
# Epoch [57/75], Step [10], Loss: 1.7614
# Epoch [57/75], Step [20], Loss: 1.4661
# Epoch [57/75], Step [30], Loss: 1.4617
# Epoch [57/75], Step [40], Loss: 1.6618
# Training accuracy for epoch 57 is 88%
# Validation accuracy for epoch 57 is 74%
# Epoch [58/75], Step [10], Loss: 1.5621
# Epoch [58/75], Step [20], Loss: 1.7549
# Epoch [58/75], Step [30], Loss: 1.5617
# Epoch [58/75], Step [40], Loss: 1.4636
# Training accuracy for epoch 58 is 88%
# Validation accuracy for epoch 58 is 74%
# Epoch [59/75], Step [10], Loss: 1.5652
# Epoch [59/75], Step [20], Loss: 1.4634
# Epoch [59/75], Step [30], Loss: 1.8578
# Epoch [59/75], Step [40], Loss: 1.6617
# Training accuracy for epoch 59 is 88%
# Validation accuracy for epoch 59 is 74%
# Epoch [60/75], Step [10], Loss: 1.7553
# Epoch [60/75], Step [20], Loss: 1.5582
# Epoch [60/75], Step [30], Loss: 1.5622
# Epoch [60/75], Step [40], Loss: 1.5600
# Training accuracy for epoch 60 is 88%
# Validation accuracy for epoch 60 is 74%
# Epoch [61/75], Step [10], Loss: 1.6616
# Epoch [61/75], Step [20], Loss: 1.4618
# Epoch [61/75], Step [30], Loss: 1.4641
# Epoch [61/75], Step [40], Loss: 1.4644
# Training accuracy for epoch 61 is 88%
# Validation accuracy for epoch 61 is 74%
# Epoch [62/75], Step [10], Loss: 1.7560
# Epoch [62/75], Step [20], Loss: 1.5583
# Epoch [62/75], Step [30], Loss: 1.5585
# Epoch [62/75], Step [40], Loss: 1.4628
# Training accuracy for epoch 62 is 88%
# Validation accuracy for epoch 62 is 74%
# Epoch [63/75], Step [10], Loss: 1.4624
# Epoch [63/75], Step [20], Loss: 1.6611
# Epoch [63/75], Step [30], Loss: 1.6591
# Epoch [63/75], Step [40], Loss: 1.4615
# Training accuracy for epoch 63 is 88%
# Validation accuracy for epoch 63 is 74%
# Epoch [64/75], Step [10], Loss: 1.6593
# Epoch [64/75], Step [20], Loss: 1.4621
# Epoch [64/75], Step [30], Loss: 1.4627
# Epoch [64/75], Step [40], Loss: 1.4630
# Training accuracy for epoch 64 is 89%
# Validation accuracy for epoch 64 is 74%
# Epoch [65/75], Step [10], Loss: 1.5617
# Epoch [65/75], Step [20], Loss: 1.4626
# Epoch [65/75], Step [30], Loss: 1.5625
# Epoch [65/75], Step [40], Loss: 1.5603
# Training accuracy for epoch 65 is 89%
# Validation accuracy for epoch 65 is 74%
# Epoch [66/75], Step [10], Loss: 1.5602
# Epoch [66/75], Step [20], Loss: 1.4617
# Epoch [66/75], Step [30], Loss: 1.5629
# Epoch [66/75], Step [40], Loss: 1.5582
# Training accuracy for epoch 66 is 89%
# Validation accuracy for epoch 66 is 74%
# Epoch [67/75], Step [10], Loss: 1.8516
# Epoch [67/75], Step [20], Loss: 1.5626
# Epoch [67/75], Step [30], Loss: 1.5620
# Epoch [67/75], Step [40], Loss: 1.5601
# Training accuracy for epoch 67 is 89%
# Validation accuracy for epoch 67 is 74%
# Epoch [68/75], Step [10], Loss: 1.5625
# Epoch [68/75], Step [20], Loss: 1.5588
# Epoch [68/75], Step [30], Loss: 1.5606
# Epoch [68/75], Step [40], Loss: 1.5627
# Training accuracy for epoch 68 is 89%
# Validation accuracy for epoch 68 is 74%
# Epoch [69/75], Step [10], Loss: 1.4617
# Epoch [69/75], Step [20], Loss: 1.6597
# Epoch [69/75], Step [30], Loss: 1.7560
# Epoch [69/75], Step [40], Loss: 1.4614
# Training accuracy for epoch 69 is 89%
# Validation accuracy for epoch 69 is 74%
# Epoch [70/75], Step [10], Loss: 1.4637
# Epoch [70/75], Step [20], Loss: 1.5612
# Epoch [70/75], Step [30], Loss: 1.4633
# Epoch [70/75], Step [40], Loss: 1.5640
# Training accuracy for epoch 70 is 89%
# Validation accuracy for epoch 70 is 74%
# Epoch [71/75], Step [10], Loss: 1.5592
# Epoch [71/75], Step [20], Loss: 1.4619
# Epoch [71/75], Step [30], Loss: 1.4628
# Epoch [71/75], Step [40], Loss: 1.5620
# Training accuracy for epoch 71 is 89%
# Validation accuracy for epoch 71 is 74%
# Epoch [72/75], Step [10], Loss: 1.5631
# Epoch [72/75], Step [20], Loss: 1.4644
# Epoch [72/75], Step [30], Loss: 1.5895
# Epoch [72/75], Step [40], Loss: 1.7552
# Training accuracy for epoch 72 is 89%
# Validation accuracy for epoch 72 is 74%
# Epoch [73/75], Step [10], Loss: 1.4620
# Epoch [73/75], Step [20], Loss: 1.5629
# Epoch [73/75], Step [30], Loss: 1.5645
# Epoch [73/75], Step [40], Loss: 1.4822
# Training accuracy for epoch 73 is 89%
# Validation accuracy for epoch 73 is 74%
# Epoch [74/75], Step [10], Loss: 1.4628
# Epoch [74/75], Step [20], Loss: 1.5627
# Epoch [74/75], Step [30], Loss: 1.6401
# Epoch [74/75], Step [40], Loss: 1.7409
# Training accuracy for epoch 74 is 91%
# Validation accuracy for epoch 74 is 73%
# Epoch [75/75], Step [10], Loss: 1.6626
# Epoch [75/75], Step [20], Loss: 1.6618
# Epoch [75/75], Step [30], Loss: 1.5603
# Epoch [75/75], Step [40], Loss: 1.6613
# Training accuracy for epoch 75 is 90%
# Validation accuracy for epoch 75 is 74%

# %% [markdown]
# ### Print training and validation plots

# %%
x = np.arange(num_epochs)

plt.figure()
plt.plot(x, train_err)
plt.plot(x, val_err)
plt.legend(['training error', 'validation error'], loc='upper right')
plt.xlabel('number of epochs')
plt.ylabel('error percentage')
plt.show()

# %% [markdown]
# ### Evaluate the MLP

# %%
correct = 0
total = 0

# For each batch of images in test set
with torch.set_grad_enabled(False):
    for images, labels in test_loader:

      # Get the images
      images = images.view(-1, 28*28)

      images = images.to(device)

      # Find the output by doing a forward pass through the network
      outputs = net(images)

      # Find the class of each sample by taking a max across the probabilities of each class
      _, predicted = torch.max(outputs.data, 1)

      # Increment 'total', and 'correct' according to whether the prediction was correct or not
      total += labels.size(0)
      correct += (predicted.cpu() == labels).sum()

print('Test accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))

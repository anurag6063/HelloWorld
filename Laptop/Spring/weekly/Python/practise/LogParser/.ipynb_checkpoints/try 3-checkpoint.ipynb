# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Jul 14 13:20:15 2018

@author: anuryadav
"""

import gensim
import os
import re
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer

import pandas as pd
import argparse

def getFileFromCL():
   
    return inputFiles

#inputFiles = getFileFromCL()
#inputFiles = ['all_chats_without_names.txt']


stemmer = SnowballStemmer("english")
stopwords = pd.read_csv('stopwords.txt')

class Sentences(object):
    def __init__(self, files):
        self.files = files
        print(self.files)
        
        self.vocabulary = set ([])
        
    def __iter__(self):
        for file in self.files:
            print('Reading file names: ', file)
            
            for line in open(file, encoding='latin1'):
                line = line.split(':')[-1:][0]
                print(line)
                words = re.findall(r'(\b[A-Za-z][a-z]{2,15}\b)', line)
                print(words)
#                words = [stemmer.stem(word.lower()) for word in words if not word.lower() in stopwords ]
#                words = [ stemmer.stem(word.lower()) for word in words if not word.lower() in stopWords]

                
                for word in words:
                    self.vocabulary.add(word)
                #print('volcabulary contains', self.vocabulary, words)
                
                yield words
                

sentences = Sentences(['chats_all_with_ts.txt'])

if os.path.isfile('model-word2vec-log.bin'):
    print("Yes, model-word2vec.bin; Model exists. Will update the existing model with new file")
    model = gensim.models.Word2Vec.load('model-word2vec.bin')
    model.build_vocab(sentences,update=True)
    model.train(sentences)
    model.save('model-word2vec-lig.bin')
else:
    print('No exsiting model found')
    model = gensim.models.Word2Vec(sentences, min_count=1,window=3,sg=1)
    model.save('model-word2vec.bin')
#model = gensim.models.Word2Vec(sentences, min_count=1)


#model.wv.vocab
#model.wv.most_similar('conceiv')
# Out:
# ['sample.txt']
# No exsiting model found
# Reading file names:  sample.txt
#  Ã¢â¬Å½Messages to this chat and calls are now secured with end-to-end encryption.
#
# ['this', 'chat', 'and', 'calls', 'are', 'now', 'secured', 'with', 'end', 'end', 'encryption']
#  Pahunch gayi oyee?
#
# ['Pahunch', 'gayi', 'oyee']
#  Yup.
#
# ['Yup']
#  Raghu ram?
#
# ['Raghu', 'ram']
#  Yo Ã°Å¸Ëâ¹
#
# []
#  Cool Ã°Å¸ËÅ½
#
# ['Cool']
#  Prabhu Ram birthday celebration se fursat mile toh jo photos h apk pas humari forward krna pls.
#
# ['Prabhu', 'Ram', 'birthday', 'celebration', 'fursat', 'mile', 'toh', 'photos', 'apk', 'pas', 'humari', 'forward', 'krna', 'pls']
#  Maate aap ki jaise aagyaa
#
# ['Maate', 'aap', 'jaise', 'aagyaa']
#  Ã¢â¬Å½image omitted
#
# ['omitted']
#  Lol Ã°Å¸Ëâ
#
# ['Lol']
#  Vo b meri ni shikha ki huuuuÃ°Å¸Â¤Â­Ã°Å¸Â¤Â­Ã°Å¸Â¤Â­Ã°Å¸Â¤ÂªÃ°Å¸Â¤ÂªÃ°Å¸Â¤Âª
#
# ['meri', 'shikha']
#  Sahi sahi
#
# ['Sahi', 'sahi']
#  ??
#
# []
#  Lol haan ussi ki lene ka plan tha. tu toh kisi aur hi duniya main thi. Pata nahi kya dhundh rahi hai neeche Ã°Å¸Ëâ¹
#
# ['Lol', 'haan', 'ussi', 'lene', 'plan', 'tha', 'toh', 'kisi', 'aur', 'duniya', 'main', 'thi', 'Pata', 'nahi', 'kya', 'dhundh', 'rahi', 'hai', 'neeche']
#
#
# []
# Waise Tum log uss din tashan marne main lage huye the. Baas beach ki pics li hai tumne. Aur hamne maze kiye.
# ['Waise', 'Tum', 'log', 'uss', 'din', 'tashan', 'marne', 'main', 'lage', 'huye', 'the', 'Baas', 'beach', 'pics', 'hai', 'tumne', 'Aur', 'hamne', 'maze', 'kiye']
# Reading file names:  sample.txt
#  Ã¢â¬Å½Messages to this chat and calls are now secured with end-to-end encryption.
#
# ['this', 'chat', 'and', 'calls', 'are', 'now', 'secured', 'with', 'end', 'end', 'encryption']
#  Pahunch gayi oyee?
#
# ['Pahunch', 'gayi', 'oyee']
#  Yup.
#
# ['Yup']
#  Raghu ram?
#
# ['Raghu', 'ram']
#  Yo Ã°Å¸Ëâ¹
#
# []
#  Cool Ã°Å¸ËÅ½
#
# ['Cool']
#  Prabhu Ram birthday celebration se fursat mile toh jo photos h apk pas humari forward krna pls.
#
# ['Prabhu', 'Ram', 'birthday', 'celebration', 'fursat', 'mile', 'toh', 'photos', 'apk', 'pas', 'humari', 'forward', 'krna', 'pls']
#  Maate aap ki jaise aagyaa
#
# ['Maate', 'aap', 'jaise', 'aagyaa']
#  Ã¢â¬Å½image omitted
#
# ['omitted']
#  Lol Ã°Å¸Ëâ
#
# ['Lol']
#  Vo b meri ni shikha ki huuuuÃ°Å¸Â¤Â­Ã°Å¸Â¤Â­Ã°Å¸Â¤Â­Ã°Å¸Â¤ÂªÃ°Å¸Â¤ÂªÃ°Å¸Â¤Âª
#
# ['meri', 'shikha']
#  Sahi sahi
#
# ['Sahi', 'sahi']
#  ??
#
# []
#  Lol haan ussi ki lene ka plan tha. tu toh kisi aur hi duniya main thi. Pata nahi kya dhundh rahi hai neeche Ã°Å¸Ëâ¹
#
# ['Lol', 'haan', 'ussi', 'lene', 'plan', 'tha', 'toh', 'kisi', 'aur', 'duniya', 'main', 'thi', 'Pata', 'nahi', 'kya', 'dhundh', 'rahi', 'hai', 'neeche']
#
#
# []
# Waise Tum log uss din tashan marne main lage huye the. Baas beach ki pics li hai tumne. Aur hamne maze kiye.
# ['Waise', 'Tum', 'log', 'uss', 'din', 'tashan', 'marne', 'main', 'lage', 'huye', 'the', 'Baas', 'beach', 'pics', 'hai', 'tumne', 'Aur', 'hamne', 'maze', 'kiye']
# Reading file names:  sample.txt
#  Ã¢â¬Å½Messages to this chat and calls are now secured with end-to-end encryption.
#
# ['this', 'chat', 'and', 'calls', 'are', 'now', 'secured', 'with', 'end', 'end', 'encryption']
#  Pahunch gayi oyee?
#
# ['Pahunch', 'gayi', 'oyee']
#  Yup.
#
# ['Yup']
#  Raghu ram?
#
# ['Raghu', 'ram']
#  Yo Ã°Å¸Ëâ¹
#
# []
#  Cool Ã°Å¸ËÅ½
#
# ['Cool']
#  Prabhu Ram birthday celebration se fursat mile toh jo photos h apk pas humari forward krna pls.
#
# ['Prabhu', 'Ram', 'birthday', 'celebration', 'fursat', 'mile', 'toh', 'photos', 'apk', 'pas', 'humari', 'forward', 'krna', 'pls']
#  Maate aap ki jaise aagyaa
#
# ['Maate', 'aap', 'jaise', 'aagyaa']
#  Ã¢â¬Å½image omitted
#
# ['omitted']
#  Lol Ã°Å¸Ëâ
#
# ['Lol']
#  Vo b meri ni shikha ki huuuuÃ°Å¸Â¤Â­Ã°Å¸Â¤Â­Ã°Å¸Â¤Â­Ã°Å¸Â¤ÂªÃ°Å¸Â¤ÂªÃ°Å¸Â¤Âª
#
# ['meri', 'shikha']
#  Sahi sahi
#
# ['Sahi', 'sahi']
#  ??
#
# []
#  Lol haan ussi ki lene ka plan tha. tu toh kisi aur hi duniya main thi. Pata nahi kya dhundh rahi hai neeche Ã°Å¸Ëâ¹
#
# ['Lol', 'haan', 'ussi', 'lene', 'plan', 'tha', 'toh', 'kisi', 'aur', 'duniya', 'main', 'thi', 'Pata', 'nahi', 'kya', 'dhundh', 'rahi', 'hai', 'neeche']
#
#
# []
# Waise Tum log uss din tashan marne main lage huye the. Baas beach ki pics li hai tumne. Aur hamne maze kiye.
# ['Waise', 'Tum', 'log', 'uss', 'din', 'tashan', 'marne', 'main', 'lage', 'huye', 'the', 'Baas', 'beach', 'pics', 'hai', 'tumne', 'Aur', 'hamne', 'maze', 'kiye']
# Reading file names:  sample.txt
#  Ã¢â¬Å½Messages to this chat and calls are now secured with end-to-end encryption.
#
# ['this', 'chat', 'and', 'calls', 'are', 'now', 'secured', 'with', 'end', 'end', 'encryption']
#  Pahunch gayi oyee?
#
# ['Pahunch', 'gayi', 'oyee']
#  Yup.
#
# ['Yup']
#  Raghu ram?
#
# ['Raghu', 'ram']
#  Yo Ã°Å¸Ëâ¹
#
# []
#  Cool Ã°Å¸ËÅ½
#
# ['Cool']
#  Prabhu Ram birthday celebration se fursat mile toh jo photos h apk pas humari forward krna pls.
#
# ['Prabhu', 'Ram', 'birthday', 'celebration', 'fursat', 'mile', 'toh', 'photos', 'apk', 'pas', 'humari', 'forward', 'krna', 'pls']
#  Maate aap ki jaise aagyaa
#
# ['Maate', 'aap', 'jaise', 'aagyaa']
#  Ã¢â¬Å½image omitted
#
# ['omitted']
#  Lol Ã°Å¸Ëâ
#
# ['Lol']
#  Vo b meri ni shikha ki huuuuÃ°Å¸Â¤Â­Ã°Å¸Â¤Â­Ã°Å¸Â¤Â­Ã°Å¸Â¤ÂªÃ°Å¸Â¤ÂªÃ°Å¸Â¤Âª
#
# ['meri', 'shikha']
#  Sahi sahi
#
# ['Sahi', 'sahi']
#  ??
#
# []
#  Lol haan ussi ki lene ka plan tha. tu toh kisi aur hi duniya main thi. Pata nahi kya dhundh rahi hai neeche Ã°Å¸Ëâ¹
#
# ['Lol', 'haan', 'ussi', 'lene', 'plan', 'tha', 'toh', 'kisi', 'aur', 'duniya', 'main', 'thi', 'Pata', 'nahi', 'kya', 'dhundh', 'rahi', 'hai', 'neeche']
#
#
# []
# Waise Tum log uss din tashan marne main lage huye the. Baas beach ki pics li hai tumne. Aur hamne maze kiye.
# ['Waise', 'Tum', 'log', 'uss', 'din', 'tashan', 'marne', 'main', 'lage', 'huye', 'the', 'Baas', 'beach', 'pics', 'hai', 'tumne', 'Aur', 'hamne', 'maze', 'kiye']
# Reading file names:  sample.txt
#  Ã¢â¬Å½Messages to this chat and calls are now secured with end-to-end encryption.
#
# ['this', 'chat', 'and', 'calls', 'are', 'now', 'secured', 'with', 'end', 'end', 'encryption']
#  Pahunch gayi oyee?
#
# ['Pahunch', 'gayi', 'oyee']
#  Yup.
#
# ['Yup']
#  Raghu ram?
#
# ['Raghu', 'ram']
#  Yo Ã°Å¸Ëâ¹
#
# []
#  Cool Ã°Å¸ËÅ½
#
# ['Cool']
#  Prabhu Ram birthday celebration se fursat mile toh jo photos h apk pas humari forward krna pls.
#
# ['Prabhu', 'Ram', 'birthday', 'celebration', 'fursat', 'mile', 'toh', 'photos', 'apk', 'pas', 'humari', 'forward', 'krna', 'pls']
#  Maate aap ki jaise aagyaa
#
# ['Maate', 'aap', 'jaise', 'aagyaa']
#  Ã¢â¬Å½image omitted
#
# ['omitted']
#  Lol Ã°Å¸Ëâ
#
# ['Lol']
#  Vo b meri ni shikha ki huuuuÃ°Å¸Â¤Â­Ã°Å¸Â¤Â­Ã°Å¸Â¤Â­Ã°Å¸Â¤ÂªÃ°Å¸Â¤ÂªÃ°Å¸Â¤Âª
#
# ['meri', 'shikha']
#  Sahi sahi
#
# ['Sahi', 'sahi']
#  ??
#
# []
#  Lol haan ussi ki lene ka plan tha. tu toh kisi aur hi duniya main thi. Pata nahi kya dhundh rahi hai neeche Ã°Å¸Ëâ¹
#
# ['Lol', 'haan', 'ussi', 'lene', 'plan', 'tha', 'toh', 'kisi', 'aur', 'duniya', 'main', 'thi', 'Pata', 'nahi', 'kya', 'dhundh', 'rahi', 'hai', 'neeche']
#
#
# []
# Waise Tum log uss din tashan marne main lage huye the. Baas beach ki pics li hai tumne. Aur hamne maze kiye.
# ['Waise', 'Tum', 'log', 'uss', 'din', 'tashan', 'marne', 'main', 'lage', 'huye', 'the', 'Baas', 'beach', 'pics', 'hai', 'tumne', 'Aur', 'hamne', 'maze', 'kiye']
# Reading file names:  sample.txt
#  Ã¢â¬Å½Messages to this chat and calls are now secured with end-to-end encryption.
#
# ['this', 'chat', 'and', 'calls', 'are', 'now', 'secured', 'with', 'end', 'end', 'encryption']
#  Pahunch gayi oyee?
#
# ['Pahunch', 'gayi', 'oyee']
#  Yup.
#
# ['Yup']
#  Raghu ram?
#
# ['Raghu', 'ram']
#  Yo Ã°Å¸Ëâ¹
#
# []
#  Cool Ã°Å¸ËÅ½
#
# ['Cool']
#  Prabhu Ram birthday celebration se fursat mile toh jo photos h apk pas humari forward krna pls.
#
# ['Prabhu', 'Ram', 'birthday', 'celebration', 'fursat', 'mile', 'toh', 'photos', 'apk', 'pas', 'humari', 'forward', 'krna', 'pls']
#  Maate aap ki jaise aagyaa
#
# ['Maate', 'aap', 'jaise', 'aagyaa']
#  Ã¢â¬Å½image omitted
#
# ['omitted']
#  Lol Ã°Å¸Ëâ
#
# ['Lol']
#  Vo b meri ni shikha ki huuuuÃ°Å¸Â¤Â­Ã°Å¸Â¤Â­Ã°Å¸Â¤Â­Ã°Å¸Â¤ÂªÃ°Å¸Â¤ÂªÃ°Å¸Â¤Âª
#
# ['meri', 'shikha']
#  Sahi sahi
#
# ['Sahi', 'sahi']
#  ??
#
# []
#  Lol haan ussi ki lene ka plan tha. tu toh kisi aur hi duniya main thi. Pata nahi kya dhundh rahi hai neeche Ã°Å¸Ëâ¹
#
# ['Lol', 'haan', 'ussi', 'lene', 'plan', 'tha', 'toh', 'kisi', 'aur', 'duniya', 'main', 'thi', 'Pata', 'nahi', 'kya', 'dhundh', 'rahi', 'hai', 'neeche']
#
#
# []
# Waise Tum log uss din tashan marne main lage huye the. Baas beach ki pics li hai tumne. Aur hamne maze kiye.
# ['Waise', 'Tum', 'log', 'uss', 'din', 'tashan', 'marne', 'main', 'lage', 'huye', 'the', 'Baas', 'beach', 'pics', 'hai', 'tumne', 'Aur', 'hamne', 'maze', 'kiye']

# %%
model.wv.most_similar('sahi')
# Out:
# [('Pata', 0.1940474957227707),
#  ('mile', 0.17653098702430725),
#  ('neeche', 0.15112189948558807),
#  ('with', 0.14023418724536896),
#  ('pas', 0.13710108399391174),
#  ('and', 0.13260367512702942),
#  ('birthday', 0.12214571982622147),
#  ('plan', 0.12103664875030518),
#  ('calls', 0.11908985674381256),
#  ('duniya', 0.11284281313419342)]

# %%
model.most_similar_cosmul( positive=[ 'tune', 'kya', 'kaha'] ,topn=3)

# %% [markdown]
# model.most_similar_cosmul?

# %%
model.most_similar_cosmul?

# %%
model.wv.most_similar('food')

# %%
model.predict_output_word(['people','nature'], topn=7)

# %%
model.wv.vocab

# %%
line = "[05/03/18, 9:02:33 PM] Kajol: Ohhh niceðŸ˜‹"

# %%
line.split(':')[3]
# Out:
# ' Ohhh niceðŸ˜‹'

# %%
line.split(':')[-1:][0]
# Out:
# ' Ohhh niceðŸ˜‹'

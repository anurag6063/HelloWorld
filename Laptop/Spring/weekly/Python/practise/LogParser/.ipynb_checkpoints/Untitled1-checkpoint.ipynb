# %%
import gensim
import os
import re
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
import pandas as pd
import argparse

# %%
class Sentences(object):
    def __init__(self, files):
        self.files = files
      #  print(self.files)
        
        self.vocabulary = set ([])
        
    def __iter__(self):
        for file in self.files:
            print('Reading file names: ', file)
            
            for line in open(file, encoding='latin1'):
                words = re.findall(r'(\b[A-Za-z][a-z]{2,15}\b)', line)
                words = [stemmer.stem(word.lower()) for word in words if not word.lower() in stopwords ]
#                words = [ stemmer.stem(word.lower()) for word in words if not word.lower() in stopWords]

                
                for word in words:
                    self.vocabulary.add(word+'OrderBook')
       #         print('volcabulary contains', self.vocabulary, words)
                
                yield words

# %%
inputFiles = ['log1.txt']
modelFile = 'model-word2vec-log1.bin'

stemmer = SnowballStemmer("english")
stopwords = pd.read_csv('stopwords.txt')

# %%
sentences = Sentences(inputFiles)

# %%
model = gensim.models.Word2Vec(sentences, min_count=1)
model.save('model-word2vec-log1.bin')
# Out:
# Reading file names:  log1.txt
# Reading file names:  log1.txt
# Reading file names:  log1.txt
# Reading file names:  log1.txt
# Reading file names:  log1.txt
# Reading file names:  log1.txt

# %%
model.wv.vocab
# Out:
# {'main': <gensim.models.keyedvectors.Vocab at 0x1901bf57198>,
#  'refresh': <gensim.models.keyedvectors.Vocab at 0x1901bf57358>,
#  'org': <gensim.models.keyedvectors.Vocab at 0x1901bf57320>,
#  'springframework': <gensim.models.keyedvectors.Vocab at 0x1901bf572e8>,
#  'context': <gensim.models.keyedvectors.Vocab at 0x1901bf57278>,
#  'annot': <gensim.models.keyedvectors.Vocab at 0x1901bf57f28>,
#  'startup': <gensim.models.keyedvectors.Vocab at 0x1901bf57ac8>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x1901bf62a20>,
#  'fri': <gensim.models.keyedvectors.Vocab at 0x1901bf67518>,
#  'oct': <gensim.models.keyedvectors.Vocab at 0x1901bf67be0>,
#  'root': <gensim.models.keyedvectors.Vocab at 0x1901bf67e48>,
#  'hierarchi': <gensim.models.keyedvectors.Vocab at 0x1901bf67f98>,
#  'javax': <gensim.models.keyedvectors.Vocab at 0x1901bf67fd0>,
#  'inject': <gensim.models.keyedvectors.Vocab at 0x1901bf67400>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x1901bf67f60>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x1901bf6cf28>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x1901bf6cb38>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x1901bf6c7f0>,
#  'autowir': <gensim.models.keyedvectors.Vocab at 0x1901bf6c128>,
#  'bean': <gensim.models.keyedvectors.Vocab at 0x1901bf6c240>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x1901bf6ce80>,
#  'cloud': <gensim.models.keyedvectors.Vocab at 0x1901bf6cb70>,
#  'autoconfigur': <gensim.models.keyedvectors.Vocab at 0x1901bf6c5c0>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x1901bf6cfd0>,
#  'elig': <gensim.models.keyedvectors.Vocab at 0x1901bf6cda0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x1901bf6cc88>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x1901bf6cac8>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x1901bf6c710>,
#  'exampl': <gensim.models.keyedvectors.Vocab at 0x1901bf6c780>,
#  'auto': <gensim.models.keyedvectors.Vocab at 0x1901bf6c828>,
#  'proxi': <gensim.models.keyedvectors.Vocab at 0x1901bf6ce48>,
#  'spring': <gensim.models.keyedvectors.Vocab at 0x1901bf6c518>,
#  'boot': <gensim.models.keyedvectors.Vocab at 0x1901bf6c9e8>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x1901bf6c6a0>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x1901bf6ca90>,
#  'profil': <gensim.models.keyedvectors.Vocab at 0x1901bf6ca58>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x1901bf6c748>,
#  'activ': <gensim.models.keyedvectors.Vocab at 0x1901bf6cc18>,
#  'dev': <gensim.models.keyedvectors.Vocab at 0x1901bf6cd68>,
#  'embed': <gensim.models.keyedvectors.Vocab at 0x1901bf6c278>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x1901bf6c940>,
#  'overrid': <gensim.models.keyedvectors.Vocab at 0x1901bf6a2b0>,
#  'definit': <gensim.models.keyedvectors.Vocab at 0x1901bf6a390>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x1901bf6a518>,
#  'differ': <gensim.models.keyedvectors.Vocab at 0x1901bf6a6a0>,
#  'replac': <gensim.models.keyedvectors.Vocab at 0x1901bf6a2e8>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x1901bf6a1d0>,
#  'null': <gensim.models.keyedvectors.Vocab at 0x1901bf6a470>,
#  'scope': <gensim.models.keyedvectors.Vocab at 0x1901bf6a4a8>,
#  'abstract': <gensim.models.keyedvectors.Vocab at 0x1901bf6a710>,
#  'fals': <gensim.models.keyedvectors.Vocab at 0x1901bf6a6d8>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x1901bf6a438>,
#  'primari': <gensim.models.keyedvectors.Vocab at 0x1901bf6a358>,
#  'netflix': <gensim.models.keyedvectors.Vocab at 0x1901bf6a0b8>,
#  'hystrix': <gensim.models.keyedvectors.Vocab at 0x1901bf6a128>,
#  'infer': <gensim.models.keyedvectors.Vocab at 0x1901bf6a7b8>,
#  'defin': <gensim.models.keyedvectors.Vocab at 0x1901bf6aa20>,
#  'path': <gensim.models.keyedvectors.Vocab at 0x1901bf6a550>,
#  'resourc': <gensim.models.keyedvectors.Vocab at 0x1901bf6a7f0>,
#  'multipl': <gensim.models.keyedvectors.Vocab at 0x1901bf6a668>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x1901bf6a780>,
#  'modul': <gensim.models.keyedvectors.Vocab at 0x1901bf6a828>,
#  'enter': <gensim.models.keyedvectors.Vocab at 0x1901bf6a860>,
#  'strict': <gensim.models.keyedvectors.Vocab at 0x1901bf6a898>,
#  'repositori': <gensim.models.keyedvectors.Vocab at 0x1901bf6a8d0>,
#  'configur': <gensim.models.keyedvectors.Vocab at 0x1901bf6a9e8>,
#  'mode': <gensim.models.keyedvectors.Vocab at 0x1901bf6a908>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x1901bf6a9b0>,
#  'instanc': <gensim.models.keyedvectors.Vocab at 0x1901bf6a978>,
#  'convert': <gensim.models.keyedvectors.Vocab at 0x1901bf6a940>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x1901bf6aa58>,
#  'env': <gensim.models.keyedvectors.Vocab at 0x1901bf6aa90>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x1901bf6aac8>,
#  'config': <gensim.models.keyedvectors.Vocab at 0x1901bf6ab00>,
#  'classpath': <gensim.models.keyedvectors.Vocab at 0x1901bf6ab38>,
#  'applic': <gensim.models.keyedvectors.Vocab at 0x1901bf6ab70>,
#  'yml': <gensim.models.keyedvectors.Vocab at 0x1901bf6aba8>,
#  'properti': <gensim.models.keyedvectors.Vocab at 0x1901bf6abe0>,
#  'bootstrap': <gensim.models.keyedvectors.Vocab at 0x1901bf6ac18>,
#  'resolv': <gensim.models.keyedvectors.Vocab at 0x1901bf6ac50>,
#  'custom': <gensim.models.keyedvectors.Vocab at 0x1901bf6ac88>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x1901bf6acc0>,
#  'initi': <gensim.models.keyedvectors.Vocab at 0x1901bf6acf8>,
#  'default': <gensim.models.keyedvectors.Vocab at 0x1901bf6ad30>,
#  'detector': <gensim.models.keyedvectors.Vocab at 0x1901bf6ad68>,
#  'metric': <gensim.models.keyedvectors.Vocab at 0x1901bf6ada0>,
#  'tomcat': <gensim.models.keyedvectors.Vocab at 0x1901bf6add8>,
#  'port': <gensim.models.keyedvectors.Vocab at 0x1901bf6ae10>,
#  'http': <gensim.models.keyedvectors.Vocab at 0x1901bf6ae48>,
#  'apach': <gensim.models.keyedvectors.Vocab at 0x1901bf6ae80>,
#  'catalina': <gensim.models.keyedvectors.Vocab at 0x1901bf6aeb8>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x1901bf6aef0>,
#  'servic': <gensim.models.keyedvectors.Vocab at 0x1901bf6af28>,
#  'servlet': <gensim.models.keyedvectors.Vocab at 0x1901bf6af60>,
#  'engin': <gensim.models.keyedvectors.Vocab at 0x1901bf6af98>,
#  'ost': <gensim.models.keyedvectors.Vocab at 0x1901bf6afd0>,
#  'localhost': <gensim.models.keyedvectors.Vocab at 0x1901bf71048>,
#  'web': <gensim.models.keyedvectors.Vocab at 0x1901bf71080>,
#  'complet': <gensim.models.keyedvectors.Vocab at 0x1901bf710b8>,
#  'map': <gensim.models.keyedvectors.Vocab at 0x1901bf710f0>,
#  'filter': <gensim.models.keyedvectors.Vocab at 0x1901bf71128>,
#  'sourc': <gensim.models.keyedvectors.Vocab at 0x1901bf71160>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x1901bf71198>,
#  'poll': <gensim.models.keyedvectors.Vocab at 0x1901bf711d0>,
#  'dynam': <gensim.models.keyedvectors.Vocab at 0x1901bf71208>,
#  'enabl': <gensim.models.keyedvectors.Vocab at 0x1901bf71240>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x1901bf71278>,
#  'archaius': <gensim.models.keyedvectors.Vocab at 0x1901bf712b0>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x1901bf712e8>,
#  'avail': <gensim.models.keyedvectors.Vocab at 0x1901bf71320>,
#  'com': <gensim.models.keyedvectors.Vocab at 0x1901bf71358>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x1901bf71390>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x1901bf713c8>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x1901bf71400>,
#  'onto': <gensim.models.keyedvectors.Vocab at 0x1901bf71438>,
#  'public': <gensim.models.keyedvectors.Vocab at 0x1901bf71470>,
#  'java': <gensim.models.keyedvectors.Vocab at 0x1901bf714a8>,
#  'lang': <gensim.models.keyedvectors.Vocab at 0x1901bf714e0>,
#  'string': <gensim.models.keyedvectors.Vocab at 0x1901bf71518>,
#  'broadcom': <gensim.models.keyedvectors.Vocab at 0x1901bf71550>,
#  'throw': <gensim.models.keyedvectors.Vocab at 0x1901bf71588>,
#  'fasterxml': <gensim.models.keyedvectors.Vocab at 0x1901bf715c0>,
#  'jackson': <gensim.models.keyedvectors.Vocab at 0x1901bf715f8>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x1901bf71630>,
#  'produc': <gensim.models.keyedvectors.Vocab at 0x1901bf71668>,
#  'text': <gensim.models.keyedvectors.Vocab at 0x1901bf716a0>,
#  'html': <gensim.models.keyedvectors.Vocab at 0x1901bf716d8>,
#  'util': <gensim.models.keyedvectors.Vocab at 0x1901bf71710>,
#  'object': <gensim.models.keyedvectors.Vocab at 0x1901bf71748>,
#  'webjar': <gensim.models.keyedvectors.Vocab at 0x1901bf71780>,
#  'handler': <gensim.models.keyedvectors.Vocab at 0x1901bf717b8>,
#  'favicon': <gensim.models.keyedvectors.Vocab at 0x1901bf717f0>,
#  'ico': <gensim.models.keyedvectors.Vocab at 0x1901bf71828>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x1901bf71860>,
#  'secur': <gensim.models.keyedvectors.Vocab at 0x1901bf71898>,
#  'password': <gensim.models.keyedvectors.Vocab at 0x1901bf718d0>,
#  'creat': <gensim.models.keyedvectors.Vocab at 0x1901bf71908>,
#  'chain': <gensim.models.keyedvectors.Vocab at 0x1901bf71940>,
#  'ant': <gensim.models.keyedvectors.Vocab at 0x1901bf71978>,
#  'pattern': <gensim.models.keyedvectors.Vocab at 0x1901bf719b0>,
#  'css': <gensim.models.keyedvectors.Vocab at 0x1901bf719e8>,
#  'imag': <gensim.models.keyedvectors.Vocab at 0x1901bf71a20>,
#  'mvc': <gensim.models.keyedvectors.Vocab at 0x1901bf71a58>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x1901bf71a90>,
#  'json': <gensim.models.keyedvectors.Vocab at 0x1901bf71ac8>,
#  'vnd': <gensim.models.keyedvectors.Vocab at 0x1901bf71b00>,
#  'actuat': <gensim.models.keyedvectors.Vocab at 0x1901bf71b38>,
#  'endpoint': <gensim.models.keyedvectors.Vocab at 0x1901bf71b70>,
#  'invok': <gensim.models.keyedvectors.Vocab at 0x1901bf71ba8>,
#  'princip': <gensim.models.keyedvectors.Vocab at 0x1901bf71be0>,
#  'auditev': <gensim.models.keyedvectors.Vocab at 0x1901bf71c18>,
#  'info': <gensim.models.keyedvectors.Vocab at 0x1901bf71c50>,
#  'paus': <gensim.models.keyedvectors.Vocab at 0x1901bf71c88>,
#  'autoconfig': <gensim.models.keyedvectors.Vocab at 0x1901bf71cc0>,
#  'valu': <gensim.models.keyedvectors.Vocab at 0x1901bf71cf8>,
#  'trace': <gensim.models.keyedvectors.Vocab at 0x1901bf71d30>,
#  'stream': <gensim.models.keyedvectors.Vocab at 0x1901bf71d68>,
#  'handl': <gensim.models.keyedvectors.Vocab at 0x1901bf71da0>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x1901bf71dd8>,
#  'configprop': <gensim.models.keyedvectors.Vocab at 0x1901bf71e10>,
#  'dump': <gensim.models.keyedvectors.Vocab at 0x1901bf71e48>,
#  'resum': <gensim.models.keyedvectors.Vocab at 0x1901bf71e80>,
#  'featur': <gensim.models.keyedvectors.Vocab at 0x1901bf71eb8>,
#  'heapdump': <gensim.models.keyedvectors.Vocab at 0x1901bf71ef0>,
#  'octet': <gensim.models.keyedvectors.Vocab at 0x1901bf71f28>,
#  'void': <gensim.models.keyedvectors.Vocab at 0x1901bf71f60>,
#  'boolean': <gensim.models.keyedvectors.Vocab at 0x1901bf71f98>,
#  'logger': <gensim.models.keyedvectors.Vocab at 0x1901bf71fd0>,
#  'consum': <gensim.models.keyedvectors.Vocab at 0x1901bf75048>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x1901bf75080>,
#  'restart': <gensim.models.keyedvectors.Vocab at 0x1901bf750b8>,
#  'environ': <gensim.models.keyedvectors.Vocab at 0x1901bf750f0>,
#  'reset': <gensim.models.keyedvectors.Vocab at 0x1901bf75128>,
#  'request': <gensim.models.keyedvectors.Vocab at 0x1901bf75160>,
#  'async': <gensim.models.keyedvectors.Vocab at 0x1901bf75198>,
#  'header': <gensim.models.keyedvectors.Vocab at 0x1901bf751d0>,
#  'authent': <gensim.models.keyedvectors.Vocab at 0x1901bf75208>,
#  'logout': <gensim.models.keyedvectors.Vocab at 0x1901bf75240>,
#  'www': <gensim.models.keyedvectors.Vocab at 0x1901bf75278>,
#  'savedrequest': <gensim.models.keyedvectors.Vocab at 0x1901bf752b0>,
#  'servletapi': <gensim.models.keyedvectors.Vocab at 0x1901bf752e8>,
#  'session': <gensim.models.keyedvectors.Vocab at 0x1901bf75320>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x1901bf75358>,
#  'intercept': <gensim.models.keyedvectors.Vocab at 0x1901bf75390>,
#  'csrf': <gensim.models.keyedvectors.Vocab at 0x1901bf753c8>,
#  'loader': <gensim.models.keyedvectors.Vocab at 0x1901bf75400>,
#  'templat': <gensim.models.keyedvectors.Vocab at 0x1901bf75438>,
#  'macro': <gensim.models.keyedvectors.Vocab at 0x1901bf75470>,
#  'ad': <gensim.models.keyedvectors.Vocab at 0x1901bf754a8>,
#  'regist': <gensim.models.keyedvectors.Vocab at 0x1901bf754e0>,
#  'exposur': <gensim.models.keyedvectors.Vocab at 0x1901bf75518>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x1901bf75550>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x1901bf75588>,
#  'autodetect': <gensim.models.keyedvectors.Vocab at 0x1901bf755c0>,
#  'locat': <gensim.models.keyedvectors.Vocab at 0x1901bf755f8>,
#  'manag': <gensim.models.keyedvectors.Vocab at 0x1901bf75630>,
#  'server': <gensim.models.keyedvectors.Vocab at 0x1901bf75668>,
#  'phase': <gensim.models.keyedvectors.Vocab at 0x1901bf756a0>,
#  'eureka': <gensim.models.keyedvectors.Vocab at 0x1901bf756d8>,
#  'status': <gensim.models.keyedvectors.Vocab at 0x1901bf75710>,
#  'provid': <gensim.models.keyedvectors.Vocab at 0x1901bf75748>,
#  'encod': <gensim.models.keyedvectors.Vocab at 0x1901bf75780>,
#  'codec': <gensim.models.keyedvectors.Vocab at 0x1901bf757b8>,
#  'decod': <gensim.models.keyedvectors.Vocab at 0x1901bf757f0>,
#  'aw': <gensim.models.keyedvectors.Vocab at 0x1901bf75828>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x1901bf75860>,
#  'discoveri': <gensim.models.keyedvectors.Vocab at 0x1901bf75898>,
#  'disabl': <gensim.models.keyedvectors.Vocab at 0x1901bf758d0>,
#  'delta': <gensim.models.keyedvectors.Vocab at 0x1901bf75908>,
#  'singl': <gensim.models.keyedvectors.Vocab at 0x1901bf75940>,
#  'vip': <gensim.models.keyedvectors.Vocab at 0x1901bf75978>,
#  'registri': <gensim.models.keyedvectors.Vocab at 0x1901bf759b0>,
#  'forc': <gensim.models.keyedvectors.Vocab at 0x1901bf759e8>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x1901bf75a20>,
#  'fetch': <gensim.models.keyedvectors.Vocab at 0x1901bf75a58>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x1901bf75a90>,
#  'zero': <gensim.models.keyedvectors.Vocab at 0x1901bf75ac8>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x1901bf75b00>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x1901bf75b38>,
#  'respons': <gensim.models.keyedvectors.Vocab at 0x1901bf75b70>,
#  'heartbeat': <gensim.models.keyedvectors.Vocab at 0x1901bf75ba8>,
#  'executor': <gensim.models.keyedvectors.Vocab at 0x1901bf75be0>,
#  'renew': <gensim.models.keyedvectors.Vocab at 0x1901bf75c18>,
#  'interv': <gensim.models.keyedvectors.Vocab at 0x1901bf75c50>,
#  'updat': <gensim.models.keyedvectors.Vocab at 0x1901bf75c88>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x1901bf75cc0>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x1901bf75cf8>,
#  'per': <gensim.models.keyedvectors.Vocab at 0x1901bf75d30>,
#  'min': <gensim.models.keyedvectors.Vocab at 0x1901bf75d68>,
#  'client': <gensim.models.keyedvectors.Vocab at 0x1901bf75da0>,
#  'timestamp': <gensim.models.keyedvectors.Vocab at 0x1901bf75dd8>,
#  'count': <gensim.models.keyedvectors.Vocab at 0x1901bf75e10>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x1901bf75e48>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x1901bf75e80>,
#  'chang': <gensim.models.keyedvectors.Vocab at 0x1901bf75eb8>,
#  'event': <gensim.models.keyedvectors.Vocab at 0x1901bf75ef0>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x1901bf75f28>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x1901bf75f60>,
#  'ash': <gensim.models.keyedvectors.Vocab at 0x1901bf75f98>,
#  'net': <gensim.models.keyedvectors.Vocab at 0x1901bf75fd0>,
#  'poller': <gensim.models.keyedvectors.Vocab at 0x1901bf77048>,
#  'registr': <gensim.models.keyedvectors.Vocab at 0x1901bf77080>,
#  'fail': <gensim.models.keyedvectors.Vocab at 0x1901bf770b8>,
#  'connector': <gensim.models.keyedvectors.Vocab at 0x1901bf770f0>,
#  'compon': <gensim.models.keyedvectors.Vocab at 0x1901bf77128>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x1901bf77160>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x1901bf77198>,
#  'reflect': <gensim.models.keyedvectors.Vocab at 0x1901bf771d0>,
#  'nativ': <gensim.models.keyedvectors.Vocab at 0x1901bf77208>,
#  'launcher': <gensim.models.keyedvectors.Vocab at 0x1901bf77240>,
#  'launch': <gensim.models.keyedvectors.Vocab at 0x1901bf77278>,
#  'caus': <gensim.models.keyedvectors.Vocab at 0x1901bf772b0>,
#  'protocol': <gensim.models.keyedvectors.Vocab at 0x1901bf772e8>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x1901bf77320>,
#  'frame': <gensim.models.keyedvectors.Vocab at 0x1901bf77358>,
#  'omit': <gensim.models.keyedvectors.Vocab at 0x1901bf77390>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x1901bf773c8>,
#  'alreadi': <gensim.models.keyedvectors.Vocab at 0x1901bf77400>,
#  'nio': <gensim.models.keyedvectors.Vocab at 0x1901bf77438>,
#  'bind': <gensim.models.keyedvectors.Vocab at 0x1901bf77470>,
#  'coyot': <gensim.models.keyedvectors.Vocab at 0x1901bf774a8>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x1901bf774e0>,
#  'display': <gensim.models.keyedvectors.Vocab at 0x1901bf77518>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x1901bf77550>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x1901bf77588>,
#  'debug': <gensim.models.keyedvectors.Vocab at 0x1901bf775c0>,
#  'descript': <gensim.models.keyedvectors.Vocab at 0x1901bf775f8>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x1901bf77630>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x1901bf77668>,
#  'misconfigur': <gensim.models.keyedvectors.Vocab at 0x1901bf776a0>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x1901bf776d8>,
#  'verifi': <gensim.models.keyedvectors.Vocab at 0x1901bf77710>,
#  'identifi': <gensim.models.keyedvectors.Vocab at 0x1901bf77748>,
#  'ani': <gensim.models.keyedvectors.Vocab at 0x1901bf77780>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x1901bf777b8>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x1901bf777f0>,
#  'anoth': <gensim.models.keyedvectors.Vocab at 0x1901bf77828>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x1901bf77860>,
#  'unregist': <gensim.models.keyedvectors.Vocab at 0x1901bf77898>,
#  'shut': <gensim.models.keyedvectors.Vocab at 0x1901bf778d0>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x1901bf77908>,
#  'deregist': <gensim.models.keyedvectors.Vocab at 0x1901bf77940>,
#  'expos': <gensim.models.keyedvectors.Vocab at 0x1901bf77978>,
#  'shutdown': <gensim.models.keyedvectors.Vocab at 0x1901bf779b0>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x1901bf779e8>,
#  'exec': <gensim.models.keyedvectors.Vocab at 0x1901bf77a20>,
#  'reciev': <gensim.models.keyedvectors.Vocab at 0x1901bf77a58>,
#  'queri': <gensim.models.keyedvectors.Vocab at 0x1901bf77a90>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x1901bf77ac8>,
#  'email': <gensim.models.keyedvectors.Vocab at 0x1901bf77b00>,
#  'sdhr': <gensim.models.keyedvectors.Vocab at 0x1901bf77b38>,
#  'prabhu': <gensim.models.keyedvectors.Vocab at 0x1901bf77b70>,
#  'gmail': <gensim.models.keyedvectors.Vocab at 0x1901bf77ba8>,
#  'impl': <gensim.models.keyedvectors.Vocab at 0x1901bf77be0>,
#  'param': <gensim.models.keyedvectors.Vocab at 0x1901bf77c18>,
#  'asset': <gensim.models.keyedvectors.Vocab at 0x1901bf77c50>,
#  'userid': <gensim.models.keyedvectors.Vocab at 0x1901bf77c88>,
#  'trap': <gensim.models.keyedvectors.Vocab at 0x1901bf77cc0>,
#  'wolkensoftwar': <gensim.models.keyedvectors.Vocab at 0x1901bf77cf8>,
#  'unit': <gensim.models.keyedvectors.Vocab at 0x1901bf77d30>,
#  'kiran': <gensim.models.keyedvectors.Vocab at 0x1901bf77d68>,
#  'rao': <gensim.models.keyedvectors.Vocab at 0x1901bf77da0>,
#  'pars': <gensim.models.keyedvectors.Vocab at 0x1901bf77dd8>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x1901bf77e10>,
#  'further': <gensim.models.keyedvectors.Vocab at 0x1901bf77e48>,
#  'occurr': <gensim.models.keyedvectors.Vocab at 0x1901bf77e80>,
#  'log': <gensim.models.keyedvectors.Vocab at 0x1901bf77eb8>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x1901bf77ef0>,
#  'invalid': <gensim.models.keyedvectors.Vocab at 0x1901bf77f28>,
#  'charact': <gensim.models.keyedvectors.Vocab at 0x1901bf77f60>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x1901bf77f98>,
#  'token': <gensim.models.keyedvectors.Vocab at 0x1901bf77fd0>,
#  'concurr': <gensim.models.keyedvectors.Vocab at 0x1901bf7b048>,
#  'worker': <gensim.models.keyedvectors.Vocab at 0x1901bf7b080>,
#  'thread': <gensim.models.keyedvectors.Vocab at 0x1901bf7b0b8>,
#  'threw': <gensim.models.keyedvectors.Vocab at 0x1901bf7b0f0>,
#  'firewal': <gensim.models.keyedvectors.Vocab at 0x1901bf7b128>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x1901bf7b160>,
#  'reject': <gensim.models.keyedvectors.Vocab at 0x1901bf7b198>,
#  'becaus': <gensim.models.keyedvectors.Vocab at 0x1901bf7b1d0>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x1901bf7b208>,
#  'valv': <gensim.models.keyedvectors.Vocab at 0x1901bf7b240>,
#  'target': <gensim.models.keyedvectors.Vocab at 0x1901bf7b278>,
#  'valid': <gensim.models.keyedvectors.Vocab at 0x1901bf7b2b0>,
#  'contain': <gensim.models.keyedvectors.Vocab at 0x1901bf7b2e8>,
#  'potenti': <gensim.models.keyedvectors.Vocab at 0x1901bf7b320>,
#  'malici': <gensim.models.keyedvectors.Vocab at 0x1901bf7b358>,
#  'nest': <gensim.models.keyedvectors.Vocab at 0x1901bf7b390>,
#  'multipart': <gensim.models.keyedvectors.Vocab at 0x1901bf7b3c8>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x1901bf7b400>,
#  'temporari': <gensim.models.keyedvectors.Vocab at 0x1901bf7b438>,
#  'upload': <gensim.models.keyedvectors.Vocab at 0x1901bf7b470>,
#  'tmp': <gensim.models.keyedvectors.Vocab at 0x1901bf7b4a8>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x1901bf7b4e0>,
#  'parser': <gensim.models.keyedvectors.Vocab at 0x1901bf7b518>,
#  'cooki': <gensim.models.keyedvectors.Vocab at 0x1901bf7b550>,
#  'receiv': <gensim.models.keyedvectors.Vocab at 0x1901bf7b588>,
#  'pass': <gensim.models.keyedvectors.Vocab at 0x1901bf7b5c0>,
#  'ignor': <gensim.models.keyedvectors.Vocab at 0x1901bf7b5f8>,
#  'paramet': <gensim.models.keyedvectors.Vocab at 0x1901bf7b630>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x1901bf7b668>,
#  'libc': <gensim.models.keyedvectors.Vocab at 0x1901bf7b6a0>,
#  'debian': <gensim.models.keyedvectors.Vocab at 0x1901bf7b6d8>,
#  'crtstuff': <gensim.models.keyedvectors.Vocab at 0x1901bf7b710>,
#  'payload': <gensim.models.keyedvectors.Vocab at 0x1901bf7b748>,
#  'symtab': <gensim.models.keyedvectors.Vocab at 0x1901bf7b780>,
#  'strtab': <gensim.models.keyedvectors.Vocab at 0x1901bf7b7b8>,
#  'shstrtab': <gensim.models.keyedvectors.Vocab at 0x1901bf7b7f0>,
#  'gnu': <gensim.models.keyedvectors.Vocab at 0x1901bf7b828>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x1901bf7b860>,
#  'hash': <gensim.models.keyedvectors.Vocab at 0x1901bf7b898>,
#  'dynsym': <gensim.models.keyedvectors.Vocab at 0x1901bf7b8d0>,
#  'dynstr': <gensim.models.keyedvectors.Vocab at 0x1901bf7b908>,
#  'rela': <gensim.models.keyedvectors.Vocab at 0x1901bf7b940>,
#  'dyn': <gensim.models.keyedvectors.Vocab at 0x1901bf7b978>,
#  'plt': <gensim.models.keyedvectors.Vocab at 0x1901bf7b9b0>,
#  'init': <gensim.models.keyedvectors.Vocab at 0x1901bf7b9e8>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x1901bf7ba20>,
#  'fini': <gensim.models.keyedvectors.Vocab at 0x1901bf7ba58>,
#  'rodata': <gensim.models.keyedvectors.Vocab at 0x1901bf7ba90>,
#  'jcr': <gensim.models.keyedvectors.Vocab at 0x1901bf7bac8>,
#  'bss': <gensim.models.keyedvectors.Vocab at 0x1901bf7bb00>,
#  'comment': <gensim.models.keyedvectors.Vocab at 0x1901bf7bb38>,
#  'quot': <gensim.models.keyedvectors.Vocab at 0x1901bf7bb70>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x1901bf7bba8>,
#  'corrupt': <gensim.models.keyedvectors.Vocab at 0x1901bf7bbe0>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x1901bf7bc18>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x1901bf7bc50>,
#  'origin': <gensim.models.keyedvectors.Vocab at 0x1901bf7bc88>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x1901bf7bcc0>,
#  'eur': <gensim.models.keyedvectors.Vocab at 0x1901bf7bcf8>}

# %%
model.wv.most_similar("startup")
# Out:
# [('annot', 0.9954569935798645),
#  ('oct', 0.9951245188713074),
#  ('config', 0.9951035380363464),
#  ('fri', 0.9936407208442688),
#  ('hystrix', 0.9927650690078735),
#  ('restart', 0.9917820692062378),
#  ('scope', 0.991320788860321),
#  ('webjar', 0.9907182455062866),
#  ('server', 0.9903053045272827),
#  ('environ', 0.9900609850883484)]
